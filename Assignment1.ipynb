# %% [markdown]
# # Homework 1 DSC 478
# ## Daniel O'Brien

# %% [markdown]
# # Question 1

# %%
#importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading in the csv file
bankTable = pd.read_csv("/Users/danielobrien/bank_data.csv", index_col=0)
bankTable.shape
# Out:
# (600, 11)

# %%
#Looking at 
bankTable.head(10)
# Out:
#          age    income  children  gender      region married  car  \
# id
# ID12101   48  17546.00         1  FEMALE  INNER_CITY      NO   NO
# ID12102   40  30085.10         3    MALE        TOWN     YES  YES
# ID12103   51  16575.40         0  FEMALE  INNER_CITY     YES  YES
# ID12104   23  20375.40         3  FEMALE        TOWN     YES   NO
# ID12105   57  50576.30         0  FEMALE       RURAL     YES   NO
# ID12106   57  37869.60         2  FEMALE        TOWN     YES   NO
# ID12107   22   8877.07         0    MALE       RURAL      NO   NO
# ID12108   58  24946.60         0    MALE        TOWN     YES  YES
# ID12109   37  25304.30         2  FEMALE    SUBURBAN     YES  YES
# ID12110   54  24212.10         2    MALE        TOWN     YES  YES
#
#         savings_acct current_acct mortgage  pep
# id
# ID12101           NO           NO       NO  YES
# ID12102           NO          YES      YES   NO
# ID12103          YES          YES       NO   NO
# ...

# %%
bankTable.dtypes
# Out:
# age               int64
# income          float64
# children          int64
# gender           object
# region           object
# married          object
# car              object
# savings_acct     object
# current_acct     object
# mortgage         object
# pep              object
# dtype: object

# %%
bankTable.describe()
# Out:
#               age        income    children
# count  600.000000    600.000000  600.000000
# mean    42.395000  27524.031217    1.011667
# std     14.424947  12899.468246    1.056752
# min     18.000000   5014.210000    0.000000
# 25%     30.000000  17264.500000    0.000000
# 50%     42.000000  24925.300000    1.000000
# 75%     55.250000  36172.675000    2.000000
# max     67.000000  63130.100000    3.000000

# %% [markdown]
# # Age, Income and Children
#
# ## Age
# The mean of age is a little above 42 years of age with the youngest age recorded as 18 years old and the oldest age of 67 years old. The median is slightly lower than the mean with a median of 42 years old. The IQR is 25.25 years with a third quartile of 55.25 years and a first quartile  of 30 years of age.
#
# ## Income
# The highest income amount is 63,130.10 and the lowest income level is 5,014.21. This gives a range of 58,115.89. The mean of income is 27,524.03 and the median is slightly lower at 24,925.30. The IQR is 18,908.18 with a third quartile of 36,172.68 and a first quartile of 17,26450.
#
# ## Children
# The minimum value for children is 0 and the maximum value is 3. This tells us that at most customers of the bank have three children, while some customers have no children. The mean number of children is slightly above 1, while the median is just a bit lower at exactly 1. The third quartile is 2 children and the first quartile is 0 children. This seems to indicate that the families with 3 children are a bit of an expection.

# %%
bankTable.groupby("gender").describe().T
# Out:
# gender                FEMALE          MALE
# age      count    300.000000    300.000000
#          mean      43.693333     41.096667
#          std       14.672545     14.077924
#          min       18.000000     18.000000
#          25%       31.000000     29.000000
#          50%       44.000000     40.000000
#          75%       57.000000     52.000000
#          max       67.000000     67.000000
# income   count    300.000000    300.000000
#          mean   27831.368233  27216.694200
#          std    13031.258242  12780.682144
#          min     7549.380000   5014.210000
#          25%    17711.100000  16805.175000
#          50%    25448.900000  24449.200000
#          75%    34873.100000  36610.850000
#          max    63130.100000  59409.100000
# children count    300.000000    300.000000
#          mean       1.026667      0.996667
#          std        1.078502      1.036131
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
# ...

# %% [markdown]
# # Gender
#
# ### Age
# The mean and median ages for females are 43.7 and 44, while the mean and median ages for men are sligtly lower at 41.1 and 40. This indicates that female customers are slightly older or there are more female customers that are older or more younger male customers. The maximum and minimum ages for both female and male customers is 67 and 18 respectively.
#
# ### Income
# The minimum and maximum income for female customers are 7,549.38 and 63,130.10 respectively, while the minimum and maximum income for male customers are 5,014.21 and 59,409.10 respectively. This shows that the highest paid female customer is paid more than the highest paid male customer and the lowest paid male customer is paid lower than the lowest paid female customer. The mean and median female incomes are 27,831.37 and 25,448.90 and the mean and median male incomes are 27,216.69 and 24,449.20. This shows that on average female customers are paid more than 600 dollars more than male customers.
#
# ### Children
# The mean number of children for female customers, 1.027, is slightly higher than the mean number of children for male customers, 0.997. This shows that the average female customer is only slightly more likely to have more children, although the difference is not great.

# %%
bankTable["region"].value_counts()
# Out:
# INNER_CITY    269
# TOWN          173
# RURAL          96
# SUBURBAN       62
# Name: region, dtype: int64

# %%
bankTable.groupby("region").describe().T
# Out:
# region            INNER_CITY         RURAL      SUBURBAN          TOWN
# age      count    269.000000     96.000000     62.000000    173.000000
#          mean      41.992565     43.010417     43.725806     42.202312
#          std       14.987306     14.396268     15.222039     13.299309
#          min       18.000000     18.000000     18.000000     19.000000
#          25%       28.000000     31.000000     30.250000     33.000000
#          50%       41.000000     44.000000     45.000000     41.000000
#          75%       56.000000     55.250000     58.000000     52.000000
#          max       67.000000     67.000000     67.000000     67.000000
# income   count    269.000000     96.000000     62.000000    173.000000
#          mean   26843.999963  30027.605417  28656.356935  26786.349653
#          std    13015.863373  13699.154297  13888.950040  11756.638715
#          min     6294.210000   8639.240000   8143.750000   5014.210000
# ...

# %% [markdown]
# # Region
# There are 4 different regions in this dataset, Innter City, Rural, Suburban and Town. Customers from the inner city make up the most customers, 269, followed by customers in town, 173, and then rural customers, 96 and the smallest number of customers come from suburban areas with 62 customers.
#
# ### Age
# The oldest and youngest customers from inner city, suburban and rural areas have the same ages with oldest customers with the age of 67 and youngest customers with an age of 18. The oldest customers from a Town are also ages 67, however the youngest customers are 19 years old. Customers from an inner city have the lowest mean age of 41.99, while customers from suburban areas have the oldest mean age of 43.73. The lowest median age is 41 for both town and inner city, while the highest median age is from suburban areas.
#
# ### Income
# The highest mean income comes from rural areas with a mean of 30027.61 and the lowest mean income comes from town with 26786.35. The highest median income come from rural areas as well with a median income of 27630.15 while the area with the lowest median income is inner city with a median income of 24262.80. The highest overall salary comes from a suburban area with a salary of 63130.10, while the lowest overall income coming from a town with a minimum income of 5014.21.
#
# ### Children
# The area with the highest mean number of children is rural areas with a mean of 1.23, the area with the lowest mean number of children is inner city areas with a mean number of children of 0.95. All areas have a minimum number of children of 0 with a maximum number of children of 3.

# %%
bankTable.groupby("married").describe().T
# Out:
# married                   NO           YES
# age      count    204.000000    396.000000
#          mean      42.186275     42.502525
#          std       14.477590     14.414918
#          min       18.000000     18.000000
#          25%       29.750000     30.000000
#          50%       43.000000     42.000000
#          75%       54.500000     55.250000
#          max       67.000000     67.000000
# income   count    204.000000    396.000000
#          mean   27674.627108  27446.451515
#          std    13391.270334  12655.229551
#          min     5014.210000   7723.930000
#          25%    16816.000000  17555.250000
#          50%    25890.650000  24718.250000
#          75%    36300.875000  36113.475000
#          max    60747.500000  63130.100000
# children count    204.000000    396.000000
#          mean       1.083333      0.974747
#          std        1.068085      1.050313
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
# ...

# %% [markdown]
# # Married
# There are more married customers, 396, than unmarried customers, 204.
#
# ### Age
# The maximum and minimum ages for married and unmarried customers is the same with 67 and 18 years of age respectively. The mean age of married customers is slightly higher than the mean of unmarried customers, 42.5 years of age to 42.2 years of age respectively. However the median age of umarried people is higher than the median age of married people, 43 and 42 years of age repsectvely.
#
# ### Income
# The minimum and maximum incomes are pretty similar for married and unmarried customers, with married customers having a slightly higher minimum and maximum. There is a min and max for married customers of 7723.93 and 63130.10 and a min and max of umarried customers of 5014.21 and 60747.50. The mean (27674.63) and median income (25,890.65) of unmarried customers is slightly higher than the mean(27,446.45) and median(24,718.25) of married customers.
#
# ### Children
# The minimum(0) and maximum(3) number of children for married and umarried customers is the same. The mean number of children for umarried customers(1.083) is slightly higher than the mean number of children for married customers(0.975)

# %%
bankTable.groupby("car").describe().T
# Out:
# car                       NO           YES
# age      count    304.000000    296.000000
#          mean      41.289474     43.530405
#          std       14.488931     14.294449
#          min       18.000000     18.000000
#          25%       28.000000     32.000000
#          50%       41.000000     43.000000
#          75%       53.250000     56.250000
#          max       67.000000     67.000000
# income   count    304.000000    296.000000
#          mean   26486.807336  28589.288176
#          std    12973.040522  12757.662091
#          min     6294.210000   5014.210000
#          25%    16383.850000  18046.675000
#          50%    23312.550000  26665.200000
#          75%    34598.275000  36591.500000
#          max    61554.600000  63130.100000
# children count    304.000000    296.000000
#          mean       0.973684      1.050676
#          std        1.055849      1.058044
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
# ...

# %% [markdown]
# # Car
# There are slightly more customers who do not own a car(304), than customers who do own a car(296).
#
# ### Age
# The mean(43.53) and median(43) ages of customers who own cars is slightly higher than the mean(41.29) and median(41) ages of customers who do not own cars. The max and min ages of customers who do and do not own cars in the same.
#
# ### Income
# The max(63,130.10) and min(5,014.21) incomes of customers who do own cars are larger and smaller respectively that the max(61,554.60) and min(6,294.21) incomes of customers who do not own cars. The mean(28589.29) and median(26665.20) incomes of people who own cars is higher than the mean(26486.81) and median(23312.55) incomes of customers who do not own cars.
#
# ### Children
# The mean number of children is higher for customers who own cars(1.05) than customers who do not own cars(0.97).

# %%
bankTable.groupby("savings_acct").describe().T
# Out:
# savings_acct              NO           YES
# age      count    186.000000    414.000000
#          mean      38.430108     44.176329
#          std       13.309129     14.566548
#          min       18.000000     18.000000
#          25%       27.000000     32.250000
#          50%       37.500000     45.000000
#          75%       48.000000     57.000000
#          max       67.000000     67.000000
# income   count    186.000000    414.000000
#          mean   22405.999194  29823.436908
#          std     8151.117426  13945.481952
#          min     7549.380000   5014.210000
#          25%    16307.225000  17886.525000
#          50%    22281.250000  27734.600000
#          75%    27968.225000  41005.225000
#          max    39547.800000  63130.100000
# children count    186.000000    414.000000
#          mean       0.946237      1.041063
#          std        1.069130      1.051117
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
# ...

# %% [markdown]
# # Savings Account
# There are 414 customers who have savings accounts and 186 customers who do not have savings accounts.
#
# ### Age
# The minimum and maximum ages for customers with and without savings accounts are the same. The mean(44.18) and median(45) ages of customers with savings accounts is considerably higher than the mean(38.43) and median(37.5) ages of customers without savings accounts. The IQR of ages of customers with savings accounts is 24.75, while the IQR of ages of customers without savings accounts is 21, this shows us that there is a wider age range of customers who have a savings account.
#
# ### Income
# The mean(29,823.44) and median(27,734.60) incomes of customers with savings accounts is higher than the mean(22,406) and median(22281.25) incomes of customers without savings accounts.
#
# ### Children
# The mean number of children with savings accounts(1.04) is higher than the mean number of children for customers without savings account(0.94).

# %%
bankTable.groupby("current_acct").describe().T
# Out:
# current_acct              NO           YES
# age      count    145.000000    455.000000
#          mean      43.296552     42.107692
#          std       13.741727     14.638953
#          min       18.000000     18.000000
#          25%       32.000000     29.000000
#          50%       42.000000     42.000000
#          75%       57.000000     54.000000
#          max       67.000000     67.000000
# income   count    145.000000    455.000000
#          mean   26802.195655  27754.066725
#          std    11841.829836  13222.825776
#          min     7606.250000   5014.210000
#          25%    17839.900000  17144.350000
#          50%    24554.100000  25132.900000
#          75%    33615.400000  36594.000000
#          max    57880.700000  63130.100000
# children count    145.000000    455.000000
#          mean       1.000000      1.015385
#          std        1.060660      1.056647
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
# ...

# %% [markdown]
# # Current Account
# There are 455 customers who currently have an account and 145 customers who do not currently have an account.
#
# ### Age
# The median age of customers with and without an account is the same at 42 years old. The mean age of customers without an account is slightly higher than customers without an account at 43.40 and 42.1 respectively.
#
# ### Income
# The mean(27754.07) and median(25132.90) income of customers with an account is slightly higher than the mean(26802.2) and median(24554.10) income of customers without an account.
#
# ### Children
# The number of children for customers with and without an account is very similar. There is a slightly higher mean number of children for customers with an account(1.02) than the mean number of children for customers without and account(1).

# %%
bankTable.groupby("mortgage").describe().T
# Out:
# mortgage                  NO           YES
# age      count    391.000000    209.000000
#          mean      42.565217     42.076555
#          std       14.461805     14.384951
#          min       18.000000     18.000000
#          25%       30.000000     31.000000
#          50%       43.000000     41.000000
#          75%       54.500000     56.000000
#          max       67.000000     67.000000
# income   count    391.000000    209.000000
#          mean   27662.194680  27265.553158
#          std    13199.249366  12345.988391
#          min     7549.380000   5014.210000
#          25%    17144.350000  17866.900000
#          50%    25127.700000  24763.300000
#          75%    36434.600000  34852.300000
#          max    63130.100000  60747.500000
# children count    391.000000    209.000000
#          mean       1.069054      0.904306
#          std        1.073140      1.019252
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
# ...

# %% [markdown]
# # Mortgage
# 209 customers also have a mortgage, and 391 customers do not have a mortgage.
#
# ### Age
# The ages of customers with and without mortgages is pretty similar. The mean(42.57) and median(43) ages of customers without a mortgage is slightly higher than the mean(42.08) and median(41) ages of customers with a mortgage.
#
# ### Income
# The mean(27662.19) and median(25127.70) income is slightly higher for customers without a mortgage than the mean(27265.55) and median(24763.30) income for customers with a mortgage.
#
# ### Children
# The mean number of children for customers without a mortgage(1.07) is slightly higher than the mean number of children for customers without a mortgage(0.90)

# %%
bankTable.groupby("pep").describe().T
# Out:
# pep                       NO           YES
# age      count    326.000000    274.000000
#          mean      40.098160     45.127737
#          std       14.123506     14.327991
#          min       18.000000     18.000000
#          25%       27.000000     34.000000
#          50%       40.000000     45.000000
#          75%       51.000000     58.000000
#          max       67.000000     67.000000
# income   count    326.000000    274.000000
#          mean   24900.953374  30644.919453
#          std    11661.123422  13609.613043
#          min     5014.210000   7756.360000
#          25%    15366.475000  19639.475000
#          50%    23105.000000  28080.050000
#          75%    31210.900000  38458.350000
#          max    61554.600000  63130.100000
# children count    326.000000    274.000000
#          mean       1.067485      0.945255
#          std        1.195524      0.860571
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
# ...

# %% [markdown]
# # Pep
# There are 274 customers who use the Pep product and 326 customers who do not use the Pep product.
#
# ### Age
# The mean(45.13) and median(45) age of customers who use the Pep product is higher than the mean(40.1) and median(40) income of customers who do not use the Pep product.
#
# ### Income
# The mean(30,644.92) and median(28,080.05) income is higher for customers who use the Pep product than the mean(24,900.95) and median(23,105.00) income for customers who do not use the Pep product.
#
# ### Children
# The mean number of children for customers who do not use the Pep product (1.07) is slightly higher than the mean number of children for customers who use the Pep product(0.94)

# %% [markdown]
# # Question 2

# %%
pepCust = bankTable[(bankTable.pep =='YES')]
noPepCust = bankTable[(bankTable.pep=='NO')]
pepCust.head(10)
# Out:
#          age    income  children  gender      region married  car  \
# id
# ID12101   48  17546.00         1  FEMALE  INNER_CITY      NO   NO
# ID12106   57  37869.60         2  FEMALE        TOWN     YES   NO
# ID12107   22   8877.07         0    MALE       RURAL      NO   NO
# ID12113   44  15735.80         1  FEMALE        TOWN     YES   NO
# ID12114   66  55204.70         1  FEMALE        TOWN     YES  YES
# ID12119   62  26909.20         0  FEMALE  INNER_CITY     YES   NO
# ID12121   61  57880.70         2    MALE  INNER_CITY     YES   NO
# ID12128   39  20114.00         1  FEMALE        TOWN     YES   NO
# ID12130   61  24270.10         1    MALE       RURAL     YES   NO
# ID12133   45  23443.20         1    MALE    SUBURBAN     YES  YES
#
#         savings_acct current_acct mortgage  pep
# id
# ID12101           NO           NO       NO  YES
# ID12106          YES          YES       NO  YES
# ID12107           NO          YES       NO  YES
# ...

# %%
noPepCust.head(10)
# Out:
#          age   income  children  gender      region married  car savings_acct  \
# id
# ID12102   40  30085.1         3    MALE        TOWN     YES  YES           NO
# ID12103   51  16575.4         0  FEMALE  INNER_CITY     YES  YES          YES
# ID12104   23  20375.4         3  FEMALE        TOWN     YES   NO           NO
# ID12105   57  50576.3         0  FEMALE       RURAL     YES   NO          YES
# ID12108   58  24946.6         0    MALE        TOWN     YES  YES          YES
# ID12109   37  25304.3         2  FEMALE    SUBURBAN     YES  YES           NO
# ID12110   54  24212.1         2    MALE        TOWN     YES  YES          YES
# ID12111   66  59803.9         0  FEMALE        TOWN     YES   NO          YES
# ID12112   52  26658.8         0  FEMALE  INNER_CITY      NO  YES          YES
# ID12115   36  19474.6         0    MALE       RURAL     YES   NO          YES
#
#         current_acct mortgage pep
# id
# ID12102          YES      YES  NO
# ...

# %%
pepCust.describe()
# Out:
#               age        income    children
# count  274.000000    274.000000  274.000000
# mean    45.127737  30644.919453    0.945255
# std     14.327991  13609.613043    0.860571
# min     18.000000   7756.360000    0.000000
# 25%     34.000000  19639.475000    0.000000
# 50%     45.000000  28080.050000    1.000000
# 75%     58.000000  38458.350000    1.000000
# max     67.000000  63130.100000    3.000000

# %%
noPepCust.describe()
# Out:
#               age        income    children
# count  326.000000    326.000000  326.000000
# mean    40.098160  24900.953374    1.067485
# std     14.123506  11661.123422    1.195524
# min     18.000000   5014.210000    0.000000
# 25%     27.000000  15366.475000    0.000000
# 50%     40.000000  23105.000000    0.000000
# 75%     51.000000  31210.900000    2.000000
# max     67.000000  61554.600000    3.000000

# %%
pepCust["region"].value_counts()
# Out:
# INNER_CITY    123
# TOWN           71
# RURAL          46
# SUBURBAN       34
# Name: region, dtype: int64

# %%
noPepCust["region"].value_counts()
# Out:
# INNER_CITY    146
# TOWN          102
# RURAL          50
# SUBURBAN       28
# Name: region, dtype: int64

# %%
pepCust["gender"].value_counts()
# Out:
# MALE      144
# FEMALE    130
# Name: gender, dtype: int64

# %%
noPepCust["gender"].value_counts()
# Out:
# FEMALE    170
# MALE      156
# Name: gender, dtype: int64

# %%
pepCust["married"].value_counts()
# Out:
# YES    154
# NO     120
# Name: married, dtype: int64

# %%
noPepCust["married"].value_counts()
# Out:
# YES    242
# NO      84
# Name: married, dtype: int64

# %%
pepCust["car"].value_counts()
# Out:
# YES    138
# NO     136
# Name: car, dtype: int64

# %%
noPepCust["car"].value_counts()
# Out:
# NO     168
# YES    158
# Name: car, dtype: int64

# %%
pepCust["savings_acct"].value_counts()
# Out:
# YES    179
# NO      95
# Name: savings_acct, dtype: int64

# %%
noPepCust["savings_acct"].value_counts()
# Out:
# YES    235
# NO      91
# Name: savings_acct, dtype: int64

# %%
pepCust["current_acct"].value_counts()
# Out:
# YES    211
# NO      63
# Name: current_acct, dtype: int64

# %%
noPepCust["current_acct"].value_counts()
# Out:
# YES    244
# NO      82
# Name: current_acct, dtype: int64

# %%
pepCust["mortgage"].value_counts()
# Out:
# NO     182
# YES     92
# Name: mortgage, dtype: int64

# %%
noPepCust["mortgage"].value_counts()
# Out:
# NO     209
# YES    117
# Name: mortgage, dtype: int64

# %% [markdown]
# # Pep Vs No Pep
#
# ### Age
# The average customer who buys a Pep is about 5 years older than the average customer who does not buy the Pep product. The mean of customers who buy the Pep is 45.13 years of age, while the mean age of customers who do not buy the Pep is 40.1 years of age. For customers who purchase the Pep product, the 3rd quartile is 58 years of age and the 1st quartile is 34 years of age, which gives IQR of 24 years. For customers who do not purchase the Pep product, the 3rd quartile is 51 years of age, and the 1st quartile is 27 years of age, which gives an IQR of 24 years also. This shows that customers who buy the Pep product tend to be older than customers who do not buy the Pep product.
#
# ### Income
# The average income for customers who purchase a Pep product is 5,743.97 more than the income of customers who have not purchased a Pep product. The average income for customers who purchased a Pep product is 30,644.92 and the average income for customers who did not purchase a Pep product is 24,900.95. The 1st and 3rd quartile for customers who purchased a Pep product are 19,639.48 and 38,458.35 respectively, with an IQR of 18,818.87. The 1st and 3rd quartile for customers who did not purchase a Pep product are 15,366.48 and 31,210.90 respectively, with an IQR of 15,844.42. This shows that customers who purchase the Pep product tend to earn a higher income than customers who do not purchase a Pep product.
#
# ### Children
# The mean number of children for customers who do not use the Pep product (1.07) is slightly higher than the mean number of children for customers who use the Pep product(0.94). Additionally, customers who purchase a Pep product have a 3rd quartile number of students of 1, while customers who did not purchase the Pep product have a 3rd quartile of 2 children. This shows that less than 25% of customers who use the Pep product have more than 1 child. This indicates that customers or potential customers who have 1 child or less are more likely to be interested in the Pep product than customers or potential customers with more than 1 child.
#
# ### Gender
# There are 144 male customers and 130 female customers who purchase the Pep product. There are 170 male customers and 156 female customers who do not use the Pep product. About 46% of current male customers use the Pep proudct and about 45% of current female customers use the Pep product. There are more male customers overall, and more male than female customers that both use and do not use the Pep product.
#
# ### Region
# 123 inner city customers out of 269 total inner city customers use the Pep product, this makes up about 46% of inner city customers. There are 71 out of a total of 173 customers from towns that use the Pep product, this makes up about 41% of customers from towns. There are 46 out of 96 customers from rural areas that use the Pep product, which makes up almost 48% of rural customers. There are 34 out of 62 customers from suburban regions that use the Pep product, this makes up almost 56% of suburban customers. This shows that of the current customers, suburban customers are the most likely to use the Pep product, with customers from towns being the least likely to use the Pep product.
#
# ### Married
# Of the 396 married customers, 154 use the Pep product, this give us the percentage of about 39%. Of the 204 unmarried customers, 120 use the Pep product, or 59%. This shows that of the current customers, unmarried customers are more likely to purchase the Pep product.
#
# ### Car
# Of the 306 customers who own a car, 138 or 45% of them purchased the Pep product. Of the 294 customers who do not own a car, 136 or 46% of them have purchased the Pep product, this is not a very big difference.
#
# ### Savings Account
# Of the 414 customers who have a savings account, 179 have purchased the Pep product, this makes up 43% of customers who have a savings account. Of the 186 customers who do not have a savings account, 95 have purchased the Pep product, this makes up, 51%. This shows that customers who do not have a savings account are more likely to have purchased the Pep product.
#
# ### Current Account
# Of the 455 customers who currently have an account, 211 of them have purchased the Pep product, this makes up 46% of customers. Of the 145 customers who currently do not have an account, 63 of them have purchased the Pep product, this makes up 43%. This shows that customers who currently have an account are more likely that have purchased the Pep product.
#
# ### Mortgage
# Of the 391 customers who have a mortgage, 182 of them have purchased the Pep product, giving us about 47% of customers that have a mortgage. Of the 209 customers who do not have a mortgage, 92 of them have purchased the Pep product, giving us 44% of current customers who do not have a mortgage. This shows that customers without a mortgage are less likely to purchase the Pep product.

# %% [markdown]
# # Question 3

# %%
income_z = (bankTable["income"] - bankTable["income"].mean())/bankTable["income"].std()
income_z.head(5)
# Out:
# id
# ID12101   -0.773523
# ID12102    0.198541
# ID12103   -0.848766
# ID12104   -0.554180
# ID12105    1.787071
# Name: income, dtype: float64

# %% [markdown]
# # Question 4

# %%
age_bin = pd.qcut(bankTable.age, 3)
age_bin.head(5)
# Out:
# id
# ID12101      (35.0, 49.0]
# ID12102      (35.0, 49.0]
# ID12103      (49.0, 67.0]
# ID12104    (17.999, 35.0]
# ID12105      (49.0, 67.0]
# Name: age, dtype: category
# Categories (3, interval[float64]): [(17.999, 35.0] < (35.0, 49.0] < (49.0, 67.0]]

# %% [markdown]
# # Question 5

# %%
ageMinMax = (bankTable["age"] - bankTable["age"].min())/ (bankTable["age"].max() - bankTable["age"].min())

# %%
ageMinMax.head(10)
# Out:
# id
# ID12101    0.612245
# ID12102    0.448980
# ID12103    0.673469
# ID12104    0.102041
# ID12105    0.795918
# ID12106    0.795918
# ID12107    0.081633
# ID12108    0.816327
# ID12109    0.387755
# ID12110    0.734694
# Name: age, dtype: float64

# %%
IncomeMinMax = (bankTable["income"] - bankTable["income"].min())/ (bankTable["income"].max() - bankTable["income"].min())
IncomeMinMax.head(5)
# Out:
# id
# ID12101    0.215634
# ID12102    0.431395
# ID12103    0.198933
# ID12104    0.264320
# ID12105    0.783987
# Name: income, dtype: float64

# %%
ChildrenMinMax = (bankTable["children"] - bankTable["children"].min())/ (bankTable["children"].max() - bankTable["children"].min())
ChildrenMinMax.head(5)
# Out:
# id
# ID12101    0.333333
# ID12102    1.000000
# ID12103    0.000000
# ID12104    1.000000
# ID12105    0.000000
# Name: children, dtype: float64

# %% [markdown]
# # Question 6

# %%
bankTableNew = bankTable.drop(columns=["age", "income", "children"])
bankTableNew.head()
# Out:
#          gender      region married  car savings_acct current_acct mortgage  \
# id
# ID12101  FEMALE  INNER_CITY      NO   NO           NO           NO       NO
# ID12102    MALE        TOWN     YES  YES           NO          YES      YES
# ID12103  FEMALE  INNER_CITY     YES  YES          YES          YES       NO
# ID12104  FEMALE        TOWN     YES   NO           NO          YES       NO
# ID12105  FEMALE       RURAL     YES   NO          YES           NO       NO
#
#          pep
# id
# ID12101  YES
# ID12102   NO
# ID12103   NO
# ID12104   NO
# ID12105   NO

# %%
bankTableNew["age"] = ageMinMax
bankTableNew.head()
# Out:
#          gender      region married  car savings_acct current_acct mortgage  \
# id
# ID12101  FEMALE  INNER_CITY      NO   NO           NO           NO       NO
# ID12102    MALE        TOWN     YES  YES           NO          YES      YES
# ID12103  FEMALE  INNER_CITY     YES  YES          YES          YES       NO
# ID12104  FEMALE        TOWN     YES   NO           NO          YES       NO
# ID12105  FEMALE       RURAL     YES   NO          YES           NO       NO
#
#          pep       age
# id
# ID12101  YES  0.612245
# ID12102   NO  0.448980
# ID12103   NO  0.673469
# ID12104   NO  0.102041
# ID12105   NO  0.795918

# %%
bankTableNew["income"] = IncomeMinMax
bankTableNew.head()
# Out:
#          gender      region married  car savings_acct current_acct mortgage  \
# id
# ID12101  FEMALE  INNER_CITY      NO   NO           NO           NO       NO
# ID12102    MALE        TOWN     YES  YES           NO          YES      YES
# ID12103  FEMALE  INNER_CITY     YES  YES          YES          YES       NO
# ID12104  FEMALE        TOWN     YES   NO           NO          YES       NO
# ID12105  FEMALE       RURAL     YES   NO          YES           NO       NO
#
#          pep       age    income
# id
# ID12101  YES  0.612245  0.215634
# ID12102   NO  0.448980  0.431395
# ID12103   NO  0.673469  0.198933
# ID12104   NO  0.102041  0.264320
# ID12105   NO  0.795918  0.783987

# %%
bankTableNew["children"] = ChildrenMinMax
bankTableNew.head()
# Out:
#          gender      region married  car savings_acct current_acct mortgage  \
# id
# ID12101  FEMALE  INNER_CITY      NO   NO           NO           NO       NO
# ID12102    MALE        TOWN     YES  YES           NO          YES      YES
# ID12103  FEMALE  INNER_CITY     YES  YES          YES          YES       NO
# ID12104  FEMALE        TOWN     YES   NO           NO          YES       NO
# ID12105  FEMALE       RURAL     YES   NO          YES           NO       NO
#
#          pep       age    income  children
# id
# ID12101  YES  0.612245  0.215634  0.333333
# ID12102   NO  0.448980  0.431395  1.000000
# ID12103   NO  0.673469  0.198933  0.000000
# ID12104   NO  0.102041  0.264320  1.000000
# ID12105   NO  0.795918  0.783987  0.000000

# %%
bankTableNew = pd.get_dummies(bankTableNew)
bankTableNew.head()
# Out:
#               age    income  children  gender_FEMALE  gender_MALE  \
# id
# ID12101  0.612245  0.215634  0.333333              1            0
# ID12102  0.448980  0.431395  1.000000              0            1
# ID12103  0.673469  0.198933  0.000000              1            0
# ID12104  0.102041  0.264320  1.000000              1            0
# ID12105  0.795918  0.783987  0.000000              1            0
#
#          region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN  \
# id
# ID12101                  1             0                0            0
# ID12102                  0             0                0            1
# ID12103                  1             0                0            0
# ID12104                  0             0                0            1
# ID12105                  0             1                0            0
#
#          married_NO  ...  car_NO  car_YES  savings_acct_NO  savings_acct_YES  \
# id                   ...
# ...

# %% [markdown]
# # Question 7

# %%
corr_Matrix = bankTableNew.corr()
corr_Matrix
# Out:
#                         age    income  children  gender_FEMALE  gender_MALE  \
# age                1.000000  0.752726  0.023572       0.090081    -0.090081
# income             0.752726  1.000000  0.036761       0.023845    -0.023845
# children           0.023572  0.036761  1.000000       0.014206    -0.014206
# gender_FEMALE      0.090081  0.023845  0.014206       1.000000    -1.000000
# gender_MALE       -0.090081 -0.023845 -0.014206      -1.000000     1.000000
# region_INNER_CITY -0.025171 -0.047564 -0.051222      -0.023459     0.023459
# region_RURAL       0.018635  0.084776  0.089902      -0.009092     0.009092
# region_SUBURBAN    0.031345  0.029824 -0.014122      -0.010951     0.010951
# region_TOWN       -0.008510 -0.036431 -0.007033       0.040472    -0.040472
# married_NO        -0.010394  0.008386  0.048716       0.021110    -0.021110
# married_YES        0.010394 -0.008386 -0.048716      -0.021110     0.021110
# ...

# %%
corr_Matrix["age"].sort_values(ascending=False)
# Out:
# age                  1.000000
# income               0.752726
# savings_acct_YES     0.184389
# pep_YES              0.173825
# gender_FEMALE        0.090081
# car_YES              0.077733
# current_acct_NO      0.035312
# region_SUBURBAN      0.031345
# children             0.023572
# region_RURAL         0.018635
# mortgage_NO          0.016154
# married_YES          0.010394
# region_TOWN         -0.008510
# married_NO          -0.010394
# mortgage_YES        -0.016154
# region_INNER_CITY   -0.025171
# current_acct_YES    -0.035312
# car_NO              -0.077733
# gender_MALE         -0.090081
# pep_NO              -0.173825
# savings_acct_NO     -0.184389
# Name: age, dtype: float64

# %%
corr_Matrix["income"].sort_values(ascending=False)
# Out:
# income               1.000000
# age                  0.752726
# savings_acct_YES     0.266164
# pep_YES              0.221991
# region_RURAL         0.084776
# car_YES              0.081556
# children             0.036761
# current_acct_YES     0.031616
# region_SUBURBAN      0.029824
# gender_FEMALE        0.023845
# mortgage_NO          0.014662
# married_NO           0.008386
# married_YES         -0.008386
# mortgage_YES        -0.014662
# gender_MALE         -0.023845
# current_acct_NO     -0.031616
# region_TOWN         -0.036431
# region_INNER_CITY   -0.047564
# car_NO              -0.081556
# pep_NO              -0.221991
# savings_acct_NO     -0.266164
# Name: income, dtype: float64

# %%
corr_Matrix["children"].sort_values(ascending=False)
# Out:
# children             1.000000
# region_RURAL         0.089902
# mortgage_NO          0.074339
# pep_NO               0.057663
# married_NO           0.048716
# savings_acct_YES     0.041536
# income               0.036761
# car_YES              0.036455
# age                  0.023572
# gender_FEMALE        0.014206
# current_acct_YES     0.006238
# current_acct_NO     -0.006238
# region_TOWN         -0.007033
# region_SUBURBAN     -0.014122
# gender_MALE         -0.014206
# car_NO              -0.036455
# savings_acct_NO     -0.041536
# married_YES         -0.048716
# region_INNER_CITY   -0.051222
# pep_YES             -0.057663
# mortgage_YES        -0.074339
# Name: children, dtype: float64

# %%
corr_Matrix["gender_FEMALE"].sort_values(ascending=False)
# Out:
# gender_FEMALE        1.000000
# age                  0.090081
# mortgage_NO          0.066465
# pep_NO               0.046843
# region_TOWN          0.040472
# income               0.023845
# married_NO           0.021110
# current_acct_YES     0.019466
# children             0.014206
# savings_acct_NO      0.007207
# car_NO               0.006667
# car_YES             -0.006667
# savings_acct_YES    -0.007207
# region_RURAL        -0.009092
# region_SUBURBAN     -0.010951
# current_acct_NO     -0.019466
# married_YES         -0.021110
# region_INNER_CITY   -0.023459
# pep_YES             -0.046843
# mortgage_YES        -0.066465
# gender_MALE         -1.000000
# Name: gender_FEMALE, dtype: float64

# %%
corr_Matrix["gender_MALE"].sort_values(ascending=False)
# Out:
# gender_MALE          1.000000
# mortgage_YES         0.066465
# pep_YES              0.046843
# region_INNER_CITY    0.023459
# married_YES          0.021110
# current_acct_NO      0.019466
# region_SUBURBAN      0.010951
# region_RURAL         0.009092
# savings_acct_YES     0.007207
# car_YES              0.006667
# car_NO              -0.006667
# savings_acct_NO     -0.007207
# children            -0.014206
# current_acct_YES    -0.019466
# married_NO          -0.021110
# income              -0.023845
# region_TOWN         -0.040472
# pep_NO              -0.046843
# mortgage_NO         -0.066465
# age                 -0.090081
# gender_FEMALE       -1.000000
# Name: gender_MALE, dtype: float64

# %%
corr_Matrix["region_INNER_CITY"].sort_values(ascending=False)
# Out:
# region_INNER_CITY    1.000000
# savings_acct_NO      0.091373
# gender_MALE          0.023459
# car_NO               0.018143
# current_acct_YES     0.007894
# married_YES          0.003254
# mortgage_YES         0.002098
# pep_YES              0.001054
# pep_NO              -0.001054
# mortgage_NO         -0.002098
# married_NO          -0.003254
# current_acct_NO     -0.007894
# car_YES             -0.018143
# gender_FEMALE       -0.023459
# age                 -0.025171
# income              -0.047564
# children            -0.051222
# savings_acct_YES    -0.091373
# region_SUBURBAN     -0.306032
# region_RURAL        -0.393444
# region_TOWN         -0.573814
# Name: region_INNER_CITY, dtype: float64

# %%
corr_Matrix["region_RURAL"].sort_values(ascending=False)
# Out:
# region_RURAL         1.000000
# children             0.089902
# income               0.084776
# mortgage_NO          0.051908
# savings_acct_YES     0.036960
# car_YES              0.024006
# married_NO           0.022649
# pep_YES              0.019714
# age                  0.018635
# gender_MALE          0.009092
# current_acct_NO      0.008496
# current_acct_YES    -0.008496
# gender_FEMALE       -0.009092
# pep_NO              -0.019714
# married_YES         -0.022649
# car_NO              -0.024006
# savings_acct_NO     -0.036960
# mortgage_YES        -0.051908
# region_SUBURBAN     -0.148158
# region_TOWN         -0.277798
# region_INNER_CITY   -0.393444
# Name: region_RURAL, dtype: float64

# %%
corr_Matrix["region_SUBURBAN"].sort_values(ascending=False)
# Out:
# region_SUBURBAN      1.000000
# pep_YES              0.062508
# car_NO               0.061184
# current_acct_YES     0.038157
# age                  0.031345
# income               0.029824
# married_YES          0.012483
# gender_MALE          0.010951
# mortgage_YES         0.004635
# savings_acct_YES     0.002605
# savings_acct_NO     -0.002605
# mortgage_NO         -0.004635
# gender_FEMALE       -0.010951
# married_NO          -0.012483
# children            -0.014122
# current_acct_NO     -0.038157
# car_YES             -0.061184
# pep_NO              -0.062508
# region_RURAL        -0.148158
# region_TOWN         -0.216080
# region_INNER_CITY   -0.306032
# Name: region_SUBURBAN, dtype: float64

# %%
corr_Matrix["region_TOWN"].sort_values(ascending=False)
# Out:
# region_TOWN          1.000000
# savings_acct_YES     0.068654
# pep_NO               0.059115
# car_YES              0.041604
# gender_FEMALE        0.040472
# mortgage_YES         0.036591
# current_acct_NO      0.027431
# married_YES          0.006369
# married_NO          -0.006369
# children            -0.007033
# age                 -0.008510
# current_acct_YES    -0.027431
# income              -0.036431
# mortgage_NO         -0.036591
# gender_MALE         -0.040472
# car_NO              -0.041604
# pep_YES             -0.059115
# savings_acct_NO     -0.068654
# region_SUBURBAN     -0.216080
# region_RURAL        -0.277798
# region_INNER_CITY   -0.573814
# Name: region_TOWN, dtype: float64

# %%
corr_Matrix["married_NO"].sort_values(ascending=False)
# Out:
# married_NO           1.000000
# pep_YES              0.189578
# current_acct_YES     0.059996
# children             0.048716
# savings_acct_NO      0.028604
# region_RURAL         0.022649
# mortgage_YES         0.021711
# gender_FEMALE        0.021110
# car_YES              0.009571
# income               0.008386
# region_INNER_CITY   -0.003254
# region_TOWN         -0.006369
# car_NO              -0.009571
# age                 -0.010394
# region_SUBURBAN     -0.012483
# gender_MALE         -0.021110
# mortgage_NO         -0.021711
# savings_acct_YES    -0.028604
# current_acct_NO     -0.059996
# pep_NO              -0.189578
# married_YES         -1.000000
# Name: married_NO, dtype: float64

# %%
corr_Matrix["married_YES"].sort_values(ascending=False)
# Out:
# married_YES          1.000000
# pep_NO               0.189578
# current_acct_NO      0.059996
# savings_acct_YES     0.028604
# mortgage_NO          0.021711
# gender_MALE          0.021110
# region_SUBURBAN      0.012483
# age                  0.010394
# car_NO               0.009571
# region_TOWN          0.006369
# region_INNER_CITY    0.003254
# income              -0.008386
# car_YES             -0.009571
# gender_FEMALE       -0.021110
# mortgage_YES        -0.021711
# region_RURAL        -0.022649
# savings_acct_NO     -0.028604
# children            -0.048716
# current_acct_YES    -0.059996
# pep_YES             -0.189578
# married_NO          -1.000000
# Name: married_YES, dtype: float64

# %%
corr_Matrix["car_YES"].sort_values(ascending=False)
# Out:
# car_YES              1.000000
# income               0.081556
# age                  0.077733
# region_TOWN          0.041604
# children             0.036455
# current_acct_NO      0.034783
# savings_acct_YES     0.034310
# region_RURAL         0.024006
# pep_YES              0.018917
# married_NO           0.009571
# mortgage_NO          0.007743
# gender_MALE          0.006667
# gender_FEMALE       -0.006667
# mortgage_YES        -0.007743
# married_YES         -0.009571
# region_INNER_CITY   -0.018143
# pep_NO              -0.018917
# savings_acct_NO     -0.034310
# current_acct_YES    -0.034783
# region_SUBURBAN     -0.061184
# car_NO              -1.000000
# Name: car_YES, dtype: float64

# %%
corr_Matrix["car_NO"].sort_values(ascending=False)
# Out:
# car_NO               1.000000
# region_SUBURBAN      0.061184
# current_acct_YES     0.034783
# savings_acct_NO      0.034310
# pep_NO               0.018917
# region_INNER_CITY    0.018143
# married_YES          0.009571
# mortgage_YES         0.007743
# gender_FEMALE        0.006667
# gender_MALE         -0.006667
# mortgage_NO         -0.007743
# married_NO          -0.009571
# pep_YES             -0.018917
# region_RURAL        -0.024006
# savings_acct_YES    -0.034310
# current_acct_NO     -0.034783
# children            -0.036455
# region_TOWN         -0.041604
# age                 -0.077733
# income              -0.081556
# car_YES             -1.000000
# Name: car_NO, dtype: float64

# %%
corr_Matrix["savings_acct_NO"].sort_values(ascending=False)
# Out:
# savings_acct_NO      1.000000
# region_INNER_CITY    0.091373
# pep_YES              0.072779
# current_acct_NO      0.042511
# car_NO               0.034310
# married_NO           0.028604
# gender_FEMALE        0.007207
# mortgage_YES         0.001588
# mortgage_NO         -0.001588
# region_SUBURBAN     -0.002605
# gender_MALE         -0.007207
# married_YES         -0.028604
# car_YES             -0.034310
# region_RURAL        -0.036960
# children            -0.041536
# current_acct_YES    -0.042511
# region_TOWN         -0.068654
# pep_NO              -0.072779
# age                 -0.184389
# income              -0.266164
# savings_acct_YES    -1.000000
# Name: savings_acct_NO, dtype: float64

# %%
corr_Matrix["savings_acct_YES"].sort_values(ascending=False)
# Out:
# savings_acct_YES     1.000000
# income               0.266164
# age                  0.184389
# pep_NO               0.072779
# region_TOWN          0.068654
# current_acct_YES     0.042511
# children             0.041536
# region_RURAL         0.036960
# car_YES              0.034310
# married_YES          0.028604
# gender_MALE          0.007207
# region_SUBURBAN      0.002605
# mortgage_NO          0.001588
# mortgage_YES        -0.001588
# gender_FEMALE       -0.007207
# married_NO          -0.028604
# car_NO              -0.034310
# current_acct_NO     -0.042511
# pep_YES             -0.072779
# region_INNER_CITY   -0.091373
# savings_acct_NO     -1.000000
# Name: savings_acct_YES, dtype: float64

# %%
corr_Matrix["current_acct_YES"].sort_values(ascending=False)
# Out:
# current_acct_YES     1.000000
# married_NO           0.059996
# savings_acct_YES     0.042511
# region_SUBURBAN      0.038157
# mortgage_NO          0.036704
# car_NO               0.034783
# income               0.031616
# pep_YES              0.025141
# gender_FEMALE        0.019466
# region_INNER_CITY    0.007894
# children             0.006238
# region_RURAL        -0.008496
# gender_MALE         -0.019466
# pep_NO              -0.025141
# region_TOWN         -0.027431
# car_YES             -0.034783
# age                 -0.035312
# mortgage_YES        -0.036704
# savings_acct_NO     -0.042511
# married_YES         -0.059996
# current_acct_NO     -1.000000
# Name: current_acct_YES, dtype: float64

# %%
corr_Matrix["current_acct_NO"].sort_values(ascending=False)
# Out:
# current_acct_NO      1.000000
# married_YES          0.059996
# savings_acct_NO      0.042511
# mortgage_YES         0.036704
# age                  0.035312
# car_YES              0.034783
# region_TOWN          0.027431
# pep_NO               0.025141
# gender_MALE          0.019466
# region_RURAL         0.008496
# children            -0.006238
# region_INNER_CITY   -0.007894
# gender_FEMALE       -0.019466
# pep_YES             -0.025141
# income              -0.031616
# car_NO              -0.034783
# mortgage_NO         -0.036704
# region_SUBURBAN     -0.038157
# savings_acct_YES    -0.042511
# married_NO          -0.059996
# current_acct_YES    -1.000000
# Name: current_acct_NO, dtype: float64

# %%
corr_Matrix["mortgage_YES"].sort_values(ascending=False)
# Out:
# mortgage_YES         1.000000
# gender_MALE          0.066465
# current_acct_NO      0.036704
# region_TOWN          0.036591
# pep_NO               0.024182
# married_NO           0.021711
# car_NO               0.007743
# region_SUBURBAN      0.004635
# region_INNER_CITY    0.002098
# savings_acct_NO      0.001588
# savings_acct_YES    -0.001588
# car_YES             -0.007743
# income              -0.014662
# age                 -0.016154
# married_YES         -0.021711
# pep_YES             -0.024182
# current_acct_YES    -0.036704
# region_RURAL        -0.051908
# gender_FEMALE       -0.066465
# children            -0.074339
# mortgage_NO         -1.000000
# Name: mortgage_YES, dtype: float64

# %%
corr_Matrix["mortgage_NO"].sort_values(ascending=False)
# Out:
# mortgage_NO          1.000000
# children             0.074339
# gender_FEMALE        0.066465
# region_RURAL         0.051908
# current_acct_YES     0.036704
# pep_YES              0.024182
# married_YES          0.021711
# age                  0.016154
# income               0.014662
# car_YES              0.007743
# savings_acct_YES     0.001588
# savings_acct_NO     -0.001588
# region_INNER_CITY   -0.002098
# region_SUBURBAN     -0.004635
# car_NO              -0.007743
# married_NO          -0.021711
# pep_NO              -0.024182
# region_TOWN         -0.036591
# current_acct_NO     -0.036704
# gender_MALE         -0.066465
# mortgage_YES        -1.000000
# Name: mortgage_NO, dtype: float64

# %%
corr_Matrix["pep_YES"].sort_values(ascending=False)
# Out:
# pep_YES              1.000000
# income               0.221991
# married_NO           0.189578
# age                  0.173825
# savings_acct_NO      0.072779
# region_SUBURBAN      0.062508
# gender_MALE          0.046843
# current_acct_YES     0.025141
# mortgage_NO          0.024182
# region_RURAL         0.019714
# car_YES              0.018917
# region_INNER_CITY    0.001054
# car_NO              -0.018917
# mortgage_YES        -0.024182
# current_acct_NO     -0.025141
# gender_FEMALE       -0.046843
# children            -0.057663
# region_TOWN         -0.059115
# savings_acct_YES    -0.072779
# married_YES         -0.189578
# pep_NO              -1.000000
# Name: pep_YES, dtype: float64

# %%
corr_Matrix["pep_NO"].sort_values(ascending=False)
# Out:
# pep_NO               1.000000
# married_YES          0.189578
# savings_acct_YES     0.072779
# region_TOWN          0.059115
# children             0.057663
# gender_FEMALE        0.046843
# current_acct_NO      0.025141
# mortgage_YES         0.024182
# car_NO               0.018917
# region_INNER_CITY   -0.001054
# car_YES             -0.018917
# region_RURAL        -0.019714
# mortgage_NO         -0.024182
# current_acct_YES    -0.025141
# gender_MALE         -0.046843
# region_SUBURBAN     -0.062508
# savings_acct_NO     -0.072779
# age                 -0.173825
# married_NO          -0.189578
# income              -0.221991
# pep_YES             -1.000000
# Name: pep_NO, dtype: float64

# %% [markdown]
# # Correlation Breakdown
# Age and income are highly correlated with correlation value of 0.75 indicating those with a higher age also tend to earn a higher income. The dummy variables with just two values, gender, married, car, mortage, and so on all have a perfect negative correlation with each other. Inner city and towns have a moderate to high negative correation with each other of -.57.

# %% [markdown]
# # Question 8

# %%
bankTable.head()
# Out:
#          age   income  children  gender      region married  car savings_acct  \
# id
# ID12101   48  17546.0         1  FEMALE  INNER_CITY      NO   NO           NO
# ID12102   40  30085.1         3    MALE        TOWN     YES  YES           NO
# ID12103   51  16575.4         0  FEMALE  INNER_CITY     YES  YES          YES
# ID12104   23  20375.4         3  FEMALE        TOWN     YES   NO           NO
# ID12105   57  50576.3         0  FEMALE       RURAL     YES   NO          YES
#
#         current_acct mortgage  pep
# id
# ID12101           NO       NO  YES
# ID12102          YES      YES   NO
# ID12103          YES       NO   NO
# ID12104          YES       NO   NO
# ID12105           NO       NO   NO

# %%
bankTable.plot(x="income", y="age", kind="scatter")

# %% [markdown]
# ## Scatterpolt breakdown
# There does appear to be a strong positive correlation between age and income. As one of the variables increases, we can see an increase in the other variable as well.

# %% [markdown]
# # Question 9

# %%
bankTable["income"].plot(kind="hist", bins=10)

# %%
bankTable["age"].plot(kind="hist", bins=14)

# %% [markdown]
# # Question 10

# %%
bankTable["region"].value_counts().plot(kind='bar', color=['red', 'blue', 'purple', 'green'])

# %% [markdown]
# # Question 11

# %%
gg = pd.crosstab(bankTable["region"], bankTable["pep"])
gg
# Out:
# pep          NO  YES
# region
# INNER_CITY  146  123
# RURAL        50   46
# SUBURBAN     28   34
# TOWN        102   71

# %%
plt.show(gg.plot(kind="bar"))
