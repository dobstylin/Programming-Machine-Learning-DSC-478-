# %% [markdown]
# ## Homework 4 Part 1
# ## Daniel O'Brien

# %%
import numpy as np
import pandas as pd

# %%
dataMat = np.genfromtxt('modified_jester_data.csv', delimiter=',')

# %%
print(dataMat)
print(dataMat.shape)
# Out:
# [[ 3.18 19.79  1.34 ...  0.    0.    0.  ]
#  [15.08 10.71 17.36 ... 11.34  6.68 12.07]
#  [ 0.    0.    0.   ...  0.    0.    0.  ]
#  ...
#  [16.58 16.63 15.85 ...  0.    0.    0.  ]
#  [ 3.67  4.45  3.67 ...  3.77  3.77  3.28]
#  [ 9.88 11.73  9.16 ...  0.    0.    0.  ]]
# (1000, 100)

# %%
jokes =  pd.read_csv("jokes.csv", header=None)

# %%
jokes.shape
# Out:
# (100, 2)

# %%
jokes = jokes.drop(columns=[0])
jokes
# Out:
#                                                     1
# 0   A man visits the doctor. The doctor says "I ha...
# 1   This couple had an excellent relationship goin...
# 2   Q. What's 200 feet long and has 4 teeth? A. Th...
# 3   Q. What's the difference between a man and a t...
# 4   Q. What's O. J. Simpson's Internet address? A....
# ..                                                ...
# 95  Two attorneys went into a diner and ordered tw...
# 96  A teacher is explaining to her class how diffe...
# 97  Age and Womanhood1. Between the ages of 13 and...
# 98  A bus station is where a bus stops.A train sta...
# 99  Q: What's the difference between greeting a Qu...
#
# [100 rows x 1 columns]

# %%
# %load itemBasedRec.py
from numpy import *
from numpy import linalg as la
import numpy as np
from operator import itemgetter

def ecludSim(inA,inB):
    return 1.0 / (1.0 + la.norm(inA - inB))

def pearsSim(inA,inB):
    if len(inA) < 3 : return 1.0
    return 0.5 + 0.5 * corrcoef(inA, inB, rowvar = 0)[0][1]

def cosSim(inA,inB):
    num = float(inA.T * inB)
    denom = la.norm(inA)*la.norm(inB)
    return 0.5 + 0.5 * (num / denom)

def standEst(dataMat, user, simMeas, item):
    n = shape(dataMat)[1]
    simTotal = 0.0; ratSimTotal = 0.0
    for j in range(n):
        userRating = dataMat[user,j]
        if userRating == 0: continue
        overLap = nonzero(logical_and(dataMat[:,item]>0, \
                                      dataMat[:,j]>0))[0]
        if len(overLap) == 0: similarity = 0
        else: similarity = simMeas(dataMat[overLap,item], \
                                   dataMat[overLap,j])
        #print 'the %d and %d similarity is: %f' % (item, j, similarity)
        simTotal += similarity
        ratSimTotal += similarity * userRating
    if simTotal == 0: return 0
    else: return ratSimTotal/simTotal
    
def svdEst(dataMat, user, simMeas, item):
    n = shape(dataMat)[1]
    simTotal = 0.0; ratSimTotal = 0.0
    data=mat(dataMat)
    U,Sigma,VT = la.svd(data)
    Sig4 = mat(eye(4)*Sigma[:4]) #arrange Sig4 into a diagonal matrix
    xformedItems = data.T * U[:,:4] * Sig4.I  #create transformed items
    for j in range(n):
        userRating = data[user,j]
        if userRating == 0 or j==item: continue
        similarity = simMeas(xformedItems[item,:].T,\
                             xformedItems[j,:].T)
        #print 'the %d and %d similarity is: %f' % (item, j, similarity)
        simTotal += similarity
        ratSimTotal += similarity * userRating
    if simTotal == 0: return 0
    else: return ratSimTotal/simTotal

# This function is not needed for Assignment 4, but may be useful for experimentation
def recommend(dataMat, user, N=3, simMeas=cosSim, estMethod=standEst):
    unratedItems = nonzero(dataMat[user,:].A==0)[1] #find unrated items 
    if len(unratedItems) == 0: return 'you rated everything'
    itemScores = []
    for item in unratedItems:
        estimatedScore = estMethod(dataMat, user, simMeas, item)
        itemScores.append((item, estimatedScore))
    return sorted(itemScores, key=lambda jj: jj[1], reverse=True)[:N]

# This function performs evaluatoin on a single user based on the test_ratio
# For example, with test_ratio = 0.2, a randomly selected 20 percent of rated 
# items by the user are withheld and the rest are used to estimate the withheld ratings

def cross_validate_user(dataMat, user, test_ratio, estMethod=standEst, simMeas=pearsSim):
	number_of_items = np.shape(dataMat)[1]
	rated_items_by_user = np.array([i for i in range(number_of_items) if dataMat[user,i]>0])
	test_size = int(test_ratio * len(rated_items_by_user))
	test_indices = np.random.randint(0, len(rated_items_by_user), test_size)
	withheld_items = rated_items_by_user[test_indices]
	original_user_profile = np.copy(dataMat[user])
	dataMat[user, withheld_items] = 0 # So that the withheld test items is not used in the rating estimation below
	error_u = 0.0
	count_u = len(withheld_items)

	# Compute absolute error for user u over all test items
	for item in withheld_items:
		# Estimate rating on the withheld item
		estimatedScore = estMethod(dataMat, user, simMeas, item)
		error_u = error_u + abs(estimatedScore - original_user_profile[item])	
	
	# Now restore ratings of the withheld items to the user profile
	for item in withheld_items:
		dataMat[user, item] = original_user_profile[item]
		
	# Return sum of absolute errors and the count of test cases for this user
	# Note that these will have to be accumulated for each user to compute MAE
	return error_u, count_u
	
def test(dataMat, test_ratio, estMethod):
    ErrorDict = {}
    count = 0 
    for row in dataMat:
        error_u, count_u = cross_validate_user(dataMat, count, test_ratio, estMethod)
        MAE = error_u/count_u
        ErrorDict[count] = MAE
        count += 1
        print ('Mean Absoloute Error for ',estMethod,' : ', MAE)
    return ErrorDict
    # Write this function to iterate over all users and for each perform evaluation by calling
    # the above cross_validate_user function on each user. MAE will be the ratio of total error 
    # across all test cases to the total number of test cases, for all users
    #print 'Mean Absoloute Error for ',estMethod,' : ', MAE

def print_most_similar_jokes(dataMat, jokes, queryJoke, k, metric=pearsSim):
    newK = k + 1
    queryJoke = dataMat[:,queryJoke]
    count = 0 
    JokeRating = {}
    for column in dataMat.T:
        rating = metric(queryJoke, column)
        JokeRating[count] = rating
        count += 1
    res = dict(sorted(JokeRating.items(), key = itemgetter(1), reverse = True)[:newK])
    firstKey = list(res.keys())[0]
    print('Selected Joke: {}'.format(jokes[firstKey]))
    del res[firstKey]
    print('The first {} jokes are:'.format(k))
    for key in res:
        print(jokes[key], '\n')

                                                
                                                #res = list(test_dict.keys())[0]
    #return res
	# Write this function to find the k most similar jokes (based on user ratings) to a queryJoke
	# The queryJoke is a joke id as given in the 'jokes.csv' file (an corresponding to the a column in dataMat)
	# You must compare ratings for the queryJoke (the column in dataMat corresponding to the joke), to all
	# other joke rating vectors and return the top k. Note that this is the same as performing KNN on the 
    # columns of dataMat. The function must retrieve the text of the joke from 'jokes.csv' file and print both
	# the queryJoke text as well as the text of the returned jokes.

def load_jokes(file):
	jokes = genfromtxt(file, delimiter=',', dtype=str)
	jokes = np.array(jokes[:,1])
	return jokes

#def get_joke_text(jokes, id):
	#return jokes[id]

# dataMat = genfromtxt('modified_jester_data.csv',delimiter=',')

# test(dataMat, 0.2, svdEst)
# test(dataMat, 0.2, standEst)

# jokes = load_jokes('jokes.csv')
# print_most_similar_jokes(dataMat, jokes, 3, 5, pearsSim)

''' See example output below:

Selected joke: 

Q. What's the difference between a man and a toilet? A. A toilet doesn't follow you around after you use it.

Top 5 Recommended jokes are :

Q: What's the difference between a Lawyer and a Plumber? A: A Plumber works to unclog the system. 
_______________
What do you call an American in the finals of the world cup? "Hey Beer Man!" 
_______________
Q. What's 200 feet long and has 4 teeth? <P>A. The front row at a Willie Nelson Concert. 
_______________
A country guy goes into a city bar that has a dress code and the maitred' demands he wear a tie. Discouraged the guy goes to his car to sulk when inspiration strikes: He's got jumper cables in the trunk! So he wrapsthem around his neck sort of like a string tie (a bulky string tie to be sure) and returns to the bar. The maitre d' is reluctant but says to the guy "Okay you're a pretty resourceful fellow you can come in... but just don't start anything"!   
_______________
What do you get when you run over a parakeet with a lawnmower? <P>Shredded tweet. 
_______________

'''
# Out:
# ' See example output below:\n\nSelected joke: \n\nQ. What\'s the difference between a man and a toilet? A. A toilet doesn\'t follow you around after you use it.\n\nTop 5 Recommended jokes are :\n\nQ: What\'s the difference between a Lawyer and a Plumber? A: A Plumber works to unclog the system. \n_______________\nWhat do you call an American in the finals of the world cup? "Hey Beer Man!" \n_______________\nQ. What\'s 200 feet long and has 4 teeth? <P>A. The front row at a Willie Nelson Concert. \n_______________\nA country guy goes into a city bar that has a dress code and the maitred\' demands he wear a tie. Discouraged the guy goes to his car to sulk when inspiration strikes: He\'s got jumper cables in the trunk! So he wrapsthem around his neck sort of like a string tie (a bulky string tie to be sure) and returns to the bar. The maitre d\' is reluctant but says to the guy "Okay you\'re a pretty resourceful fellow you can come in... but just don\'t start anything"!   \n_______________\nWhat do you get when you run over a parakeet with a lawnmower? <P>Shredded tweet. \n_______________\n\n'

# %%
jokes = load_jokes('jokes.csv')
jokes
# Out:
# array(['A man visits the doctor. The doctor says "I have bad news for you.You have cancer and Alzheimer\'s disease". The man replies "Well thank God I don\'t have cancer!"',
#        'This couple had an excellent relationship going until one day he came home from work to find his girlfriend packing. He asked her why she was leaving him and she told him that she had heard awful things about him. "What could they possibly have said to make you move out?" "They told me that you were a pedophile." He replied "That\'s an awfully big word for a ten year old."',
#        "Q. What's 200 feet long and has 4 teeth? A. The front row at a Willie Nelson Concert.",
#        "Q. What's the difference between a man and a toilet? A. A toilet doesn't follow you around after you use it.",
#        "Q. What's O. J. Simpson's Internet address? A.\tSlash slash backslash slash slash escape.",
#        "Bill & Hillary are on a trip back to Arkansas. They're almost out of gas so Bill pulls into a service station on the outskirts of town. The attendant runs out of the station to serve them when Hillary realizes it's an old boyfriend from high school. She and the attendant chat as he gases up their car and cleans the windows. Then they all say good-bye. As Bill pulls the car onto the road he turns to Hillary and says 'Now aren't you glad you married me and not him ? You could've been the wife of a grease monkey !' To which Hillary replied 'No Bill. If I would have married him you'd be pumping gas and he would be the President !'",
#        "How many feminists does it take to screw in a light bulb?That's not funny.",
#        'Q. Did you hear about the dyslexic devil worshipper? A. He sold his soul to Santa.',
#        'A country guy goes into a city bar that has a dress code and the maitred\' demands he wear a tie. Discouraged the guy goes to his car to sulk when inspiration strikes: He\'s got jumper cables in the trunk! So he wraps them around his neck sort of like a string tie (a bulky string tie to be sure) and returns to the bar. The maitre d\' is reluctant but says to the guy "Okay you\'re a pretty resourceful fellow you can come in... but just don\'t start anything"!',
#        'Two cannibals are eating a clown one turns to other and says: "Does this taste funny to you?',
#        "Q. What do a hurricane a tornado and a redneck divorce all have in common? A. Someone's going to lose their trailer...",
#        'A guy stood over his tee shot for what seemed an eternity looking up looking down measuring the distance figuring the wind direction and speed. Driving his partner nuts.Finally his exasperated partner says "What the hell is taking so long? Hit the goddamn ball!"The guy answers "My wife is up there watching me from the clubhouse. I want to make this a perfect shot.""Well hell man you don\'t stand a snowball\'s chance in hell of hitting her from here!"',
#        'They asked the Japanese visitor if they have elections in his country.  "Every Morning" he answers.',
#        'The father was very anxious to marry off his only daughter so he wanted to impress her date. "Do  you like to screw" he says. "Huh" replied the surprised first date. "My daughter she loves to screw and she\'s good at it you and her  should go screw" carefully explained the father. Now very interested the boy replied "Yes sir." Minutes later the girl came down the stairs kissed her father goodbye and the couple left. After only a few minutes she reappeared furious dress torn hair a mess and screamed"Dammit Daddy it\'s the TWIST get it straight!"',
#        'Q:  What did the blind person say when given some matzah?A:  Who the hell wrote this?',
#        'Q. What is orange and sounds like a parrot?  A. A carrot.',
#        'How many men does it take to screw in a light bulb? One...men will screw anything.',
#        'A dog walks into Western Union and asks the clerk to send a telegram. He fills out a form on which he writes down the telegram he wishes to send: "Bow wow wow Bow wow wow."The clerk says "You can add another \'Bow wow\' for the same price."The dog responded "Now wouldn\'t that sound a little silly?"',
#        'Q: If a person who speaks three languages is called "tri-lingual" and a person who speaks two languages is called "bi-lingual" what do calla person who only speaks one language?A: American!',
#        "What's the difference between a MacIntosh and anEtch-A-Sketch? You don't have to shake the Mac to clear the screen.",
#        "What's the difference between a used tire and 365 used condoms?One's a Goodyear the other's a great year.",
#        'A duck walks into a pharmacy and asks for a condom. The pharmacist says"Would you like me to stick that on your bill?"The duck says: "What kind of duck do you think I am!"',
#        "Q: What is the Australian word for a boomerang that won't   come back? A: A stick",
#        'What do you get when you run over a parakeet with a lawnmower? Shredded tweet.',
#        'Two kindergarten girls were talking outside: one said "You won\'t believe what I saw on the patio yesterday--a condom!"The second girl asked "What\'s a patio?"',
#        'A guy walks into a bar and sits down next to an extremely gorgeous woman.  The first thing he notices about her though are her pants.  They were skin-tight high-waisted and had no obvious mechanism (zipper buttons or velcro) for opening them.After several minutes of puzzling over how she got the pants up over her hips he finally worked up the nerve to ask her.  "Excuse me miss but how do you get into your pants?""Well" she replied "you can start by buying me a drink."',
#        'Clinton returns from a vacation in Arkansas and walks down  the steps of Air Force One with two pigs under his arms.  At the bottom of the steps he says  to the honor guardsman "These are genuineArkansas Razor-Back Hogs.  I got this one for Chelsea and this one forHillary."  The guardsman replies "Nice trade Sir."',
#        'A mechanical electrical and a software engineer from Microsoft were driving through the desert when the car broke down. The mechanical engineer said "It seems to be a problem with the fuel injection system why don\'t we pop the hood and I\'ll take a look at it." To which the electrical engineer replied "No I think it\'s just a loose ground wireI\'ll get out and take a look." Then the Microsoft engineer jumps in."No no no. If we just close up all the windows get out wait a few minutes get back in and then reopen the windows everything will work fine."',
#        'An old Scotsmen is sitting with a younger Scottish gentleman and says the boy. "Ah lad look out that window. You see that stone wall there I built it with me own bare hands placed every stone meself.  But do they call me MacGregor the wall builder? No! He Takes a few sips of his beer then says "Aye and look out on that lake and eye that beautiful pier. I built it meself laid every board and hammered each nail but do they call me MacGregor the pier builder? No! He continues..."And lad you see that road? That too I build with me own bare hands. Laid every inch of pavement meself but do they call MacGregor the roadbuilder? No!"Again he returns to his beer for a few sips then says "Agh but you screw one sheep..."',
#        "Q: What's the difference between a Lawyer and a Plumber? A: A Plumber works to unclog the system.",
#        ' President Clinton looks up from his desk in the Oval Office to see one of his aides nervously approach him.  "What is it?" exclaims the President. "It\'s this Abortion Bill Mr. President what do you want to do about it?" the aide replies. "Just go ahead and pay it." responds the President.',
#        'A man arrives at the gates of heaven. St. Peter asks "Religion?" The man says "Methodist." St. Peter looks down his list and says "Go to room 24 but be very quiet as you pass room 8." Another man arrives at the gates of heaven. "Religion?""Baptist." "Go to room 18 but be very quiet as you pass room 8." A third man arrives at the gates. "Religion?" "Jewish.""Go to room 11 but be very quiet as you pass room 8." The man says "I can understand there being different rooms for different religions but why must I be quiet when I pass room 8?" St. Peter tells him "Well the Catholics are in room 8 and they think they\'re the only ones here.',
#        'What do you call an American in the finals of the world cup?"Hey Beer Man!"',
#        'Out in the backwoods of some midwestern state little Johnny arrives at school an hour late.Teacher: "Why are you so late John? "Johny : "My big brother got shot in the ass."(the teacher corrects his speech)Teacher: "Rectum."Johnny : "Wrecked him!? Hell It damn near killed him!"',
#        'An explorer in the deepest Amazon suddenly finds himself surrounded by a bloodthirsty group of natives. Upon surveying the situation he says quietly to himself "Oh God I\'m screwed." The sky darkens and a voice booms out "No you are NOTscrewed. Pick up that stone at your feet and bash in the head of the chief standing in front of you." So with the stone he bashes the life out of the chief. Standing above the lifeless body breathing heavily looking at 100 angry natives... The voice booms out again "Okay ..... NOW you\'re screwed."',
#        'A guy walks into a bar orders a beer and says to the bartender"Hey I got this great Polish Joke..." The barkeep glares at him and says in a warning tone of voice:"Before you go telling that joke you better know that I\'m Polish both bouncers are Polish and so are most of my customers""Okay" says the customer"I\'ll tell it very slowly."',
#        'A Jewish young man was seeing a psychiatrist for an eating and sleeping disorder. "I am so obsessed with my mother... As soon as I go to sleep I start dreaming and everyone in my dream turns into my mother. I wake up in such a state all I can do is go downstairs and eat a piece of toast."The psychiatrist replies:"What just one piece of toast for a big boy like you?"',
#        '"May I take your order?" the waiter asked. "Yes how do you prepare your chickens?" "Nothing special sir" he replied. "We just tell them straight out that they\'re going to die."',
#        'What is the difference between men and women:A woman wants one man to satisfy her every need.A man wants every woman to satisfy his one need.',
#        'How many Irishmen does it take to change a light bulb?Two one to hold the lightbulb and the other to drink until the room spins.',
#        'What does an atheist say during an orgasm?"Oh Darwin! Oh Darwin!..."',
#        'Two men are discussing the age old question: who enjoys sex more the man or the woman?  A woman walks by and listens in for awhile and then interrupts: "Listen you guys. You know when your ear itches and you put in your little finger and wiggle it around for awhile?  Afterward which feels better your finger or your ear?"',
#        'Arnold Swartzeneger and Sylvester Stallone are making a movie about the lives of the great composers.  Stallone says "I want to be Mozart." Swartzeneger says: "In that case...  I\'ll be Bach."',
#        'A horse walks into a bar. Bartender says:"So why the long face?"',
#        'A boy comes home from school and tells his mother that he got a part in the school play.  "What part?" the mother asked. "I play a Jewish husband" the boy replied.  "Go back to school and tell your teacher that you want a speaking role!"',
#        'A couple has been married for 75 years. For the husband\'s 95thbirthday his wife decides to surprise him by hiring a prostitute.That day the doorbell rings. The husband uses his walker to get to the door and opens it. A 21-year-old in a latex outfit smiles and says "Hi I here to give you super sex!" The old man says "I\'ll take the soup."',
#        'There was an engineer who had an exceptional gift for fixing all things mechanical.  After serving his company loyally for over 30 years he happily retired.  Several years later the company contacted him regarding a seemingly impossible problem they were having with one of their multi-million dollar machines. They had tried everything and everyone else to get the machine fixed but to no avail.  In desperation they called on the retired engineer who had solved so many of their problems in the past.The engineer reluctantly took the challenge.  He spent a day studying the huge machine.  At the end of the day he marked a small "x" in chalk on a particular component of the machine and proudly stated "This is where your problem is".The part was replaced and the machine worked perfectly again. The company received a bill for $50000 from the engineer for his service.They demanded an itemized accounting of his charges. The engineer responded briefly:One chalk mark                       $1 Knowing where to put it            $49999It was paid in full and the engineer retired again in peace.',
#        'The graduate with a Science degree asks "Why does it work?"The graduate with an Engineering degree asks "How does it work?"The graduate with an Accounting degree Asks "How much will it cost?" The graduate with a  Liberal Arts degree asks "Do you want fries with  that?"',
#        'Three engineering students were gathered together discussing the possible designers of the human body.  One said "It was a mechanical engineer. Just look at all the joints."  Another said "No it was an electrical engineer.  The nervous systems many thousands of electrical connections."  The last said "Actually it was a civil engineer. Who else would run a toxic waste pipeline through a recreational area?"',
#        'A guy goes into confession and says to the priest "Father I\'m 80 years old widower with 11 grandchildren. Last night I met two beautiful flight attendants. They took me home and I made love to both of them. Twice."The priest said: "Well my son when was the last time you were in confession?" "Never Father I\'m Jewish." "So then why are you telling me?" "I\'m telling everybody."',
#        'Did you hear that Clinton has announced there is a new national bird?  The spread eagle.',
#        'Q: What do Monica Lewinsky and Bob Dole have in common?A: They were both upset when Bill finished first.',
#        'One Sunday morning William burst into the living room and said"Dad! Mom! I have some great news for you! I am getting married to the most beautiful girl in town. She lives a block away and her name is Susan."After dinner William\'s dad took him aside. "Son I have to talk with you. Your mother and I have been married 30 years.. She\'s a wonderful wife but she has never offered much excitement in the bedroom so I used to fool around with women a lot. Susan is actually your half-sister and I\'m afraid you can\'t marry her."William was heart-broken. After eight months he eventually started dating girls again. A year later he came home and very proudly announced "Dianne said yes! We\'re getting married inJune."Again his father insisted on another private conversation and broke the sad news. "Dianne is your half-sister too William. I\'m awfully sorry about this."William was furious! He finally decided to go to his mother with the news."Dad has done so much harm.. I guess I\'m never going to get married"  he complained. "Every time I fall in love Dad tells me the girl is my half-sister."His mother just shook her head. "Don\'t pay any attention to what he says dear. He\'s not really your father."',
#        'The Pope dies and naturally goes to heaven. He\'s met by the reception committee and after a whirlwind tour he is told that he can enjoy any of the myriad of recreations available.He decides that he wants to read all of the ancient original text of theHoly Scriptures so he spends the next eon or so learning languages.After becoming a linguistic master he sits down in the library and begins to pour over every version of the Bible working back from most recent "Easy Reading" to the original script.All of a sudden there is a scream in the library. The Angels come running in only to find the Pope huddled in his chair crying to himself and muttering "An \'R\'! The scribes left out the \'R\'." A particularly concerned Angel takes him aside offering comfort asks him what the problem is and what does he mean. After collecting his wits the Pope sobs again "It\'s the letter \'R\'. They left out the \'R\'.The word was supposed to be CELEBRATE!"',
#        'A woman has twins and gives them up for adoption.  One of them goes to a family in Egypt and is named "Amal."  The other goes to a  family in Spain; they name him "Juan."  Years later Juan sends a picture of himself to his mom.  Upon receiving the picture she tells her husband that she wishes she also had a picture of Amal.  Her husband responds "But they are twins-if you\'ve seen Juan you\'ve seen   Amal.',
#        'A man and Cindy Crawford get stranded on a desert island.  After a couple of days they fall in love and start sleeping together.  Time pass the man seems frustrated Cindy asks if there is anything she can do?  He says there is one thing "Could you put on this baseball cap and go to the other side of the island and answer me when I call you Bob?"  She agrees.  Next day he is walking on the other side of the island runs into her and says "Hi Bob!"  She says "Hello what\'s up?"  He replies: "Bob you won\'t believe it: I\'ve been sleeping with CindyCrawford for the past two weeks!!!!"',
#        "Why are there so many Jones's in the phone book?Because they all have phones.",
#        'How many teddy bears does it take to change a lightbulb?It takes only one teddybear but it takes a whole lot of lightbulbs.',
#        'The Chukcha (Russian Eskimo) phones up the Russian Parliament Building.  A guard answers. Chukcha:  "What is required to become Parliament member?"Guard:  "What are you an idiot?"Chukcha:  "Is it required?"',
#        'What did the Buddhist say to the hot dog vendor?Make me one with everything.',
#        'During a recent publicity outing Hillary sneaked off to visit a fortune teller of some local repute.  In a dark and hazy room peering into a crystal ball the mystic delivered grave news."There\'s no easy way to say this so I\'ll just be blunt: Prepare yourself to be a widow.  Your husband will die a violent and horrible death this year."Visibly shaken Hillary stared at the woman\'s lined face then at the single flickering candle then down at her hands.  She took a few deep breaths to compose herself.  She simply had to know.  She met the fortune teller\'s gaze steadied her voice and asked her question."Will I be acquitted?"',
#        'A group of  managers were given the assignment to measure the height of a flagpole. So they go out to the flagpole with ladders and tape measures and they\'re falling off the ladders dropping the tape measures - the whole thing is just a mess.An engineer comes along and sees what they\'re trying to do walks over pulls the flagpole out of the ground lays it flat measures it from end to end gives the measurement to one of the managers and walks away.After the engineer has gone one manager turns to another and laughs. "Isn\'t that just like an engineer we\'re looking for the height and he gives us the length."',
#        'An engineer a physicist and a mathematician are sleeping in a room. There is a fire in the room. The engineer wakes up sees the firepicks up the bucket of water and douses the fire and goes back to sleep. Again there is fire in the room. This time the physicist wakes up notices the bucket fills it with water calculates the optimal trajectory and douses the fire in minimum amount of water and goes back to sleep. Again there is fire. This time the mathematician wakes up. He looks at the fire looks at the bucket and the water and exclaims "A solution exists" and goes back to sleep.',
#        'What is the rallying cry of the International Dyslexic Pride movement? Dyslexics Untie!',
#        'Two Rednecks were seated at the end of a bar when a young lady seated a few stools up began to choke on a piece of hamburger.  She was turning blue and obviously in serious respiratory distress.One said to the other "That gal there is having a bad time!" The other agreed and said "Think we should go help?"  "You bet" said the first and with that he ran over and said "Can you breathe??"  She shook her head no.  He said "Can you speak??"  She again shook her head no.With that he pulled up her skirt and licked her on the butt.She was so shocked she coughed up the obstruction and began to breathe-with great relief.The redneck walked back to his friend and said "Funny how that hind lick maneuver always works."',
#        'A lawyer opened the door of his BMW when suddenly a car came along and hit the door ripping it off completely.  When the police arrived at the scene the lawyer was complaining bitterly about the damage to his precious BMW.  "Officer look what they\'ve done to my Beeeeemer!!!" he whined.  "You lawyers are so materialistic you make me sick!!!"  retorted the officer.  "You\'re so worried about your stupid BMW that you didn\'t even notice that your left arm was ripped off!!!"  "Oh my gaaaad..." replied the lawyer finally noticing the bloody left shoulder where his arm once was.  "Where\'s myRolex???!!!!"',
#        'Once upon a time two brooms fell in love and decided to get married.Before the ceremony the bride broom informed the groom broom that she was expecting a little whiskbroom. The groom broom was aghast!"How is this possible?" he asked. "We\'ve never swept together!',
#        'A man piloting a hot air balloon discovers he has wandered off course and is hopelessly lost. He descends to a lower altitude and locates a man down on the ground. He lowers the balloon further and shouts "Excuse me can you tell me where I am?"The man below says: "Yes you\'re in a hot air balloon about 30 feet above this field.""You must work in Information Technology" says the balloonist."Yes I do" replies the man. "And how did you know that?""Well" says the balloonist "what you told me is technically correct but of no use to anyone."The man below says "You must work in management.""I do" replies the balloonist "how did you know?""Well" says the man "you don\'t know where you are or where you\'re going but you expect my immediate help. You\'re in the same position you were before we met but now it\'s my fault!"',
#        'This guys wife asks "Honey if I died would you remarry?" and he replies "Well after a considerable period of grieving we all need companionship I guess I would."She then asks "If I died and you remarried would she live in this house?" and he replies "We\'ve spent a lot of time and money getting this house just the way we want it. I\'m not going to get rid of my house I guess she would.""If I died and you remarried and she lived in this house would she sleep in our bed?" and he says "That bed is brand new we just paid two thousand dollars for it it\'s going to last a long time I guess she would."So she asks "If I died and you remarried and she lived in this house and slept in our bed would she use my golf clubs?""Oh no she\'s left handed."',
#        'Employer to applicant: "In this job we need someone who is responsible."Applicant: "I\'m the one you want. On my last job every time anything went wrong they said I was responsible."',
#        'At a recent Sacramento PC Users Group meeting a company was demonstrating its latest speech-recognition software.   A representative from the company was just about ready to start the demonstration and asked everyone in the room to quiet down.Just then someone in the back of the room yelled"Format C: Return."Someone else chimed in:"Yes Return"Unfortunately the software worked.',
#        'On the first day of college the Dean addressed the students pointing out some of the rules:"The female dormitory will be out-of-bounds for all male students and the male dormitory to the female students. Anybody caught breaking this rule will be fined $20 the first time." He continued "Anybody caught breaking this rule the second time will be fined $60. Being caught a third time will cost you a fine of $180. Are there any questions ?"At this point a male student in the crowd inquired:"How much for a season pass ?"',
#        "Q: What is the difference between George  Washington Richard Nixon and Bill Clinton? A: Washington couldn't tell a lie Nixon couldn't   tell the truth andClinton doesn't know the difference.",
#        'Q: How many stalkers does it take to change a light bulb?A: Two. One to replace the bulb and the other to watch it day and night.',
#        'Q: Do you know the difference between an intelligent male and theSasquatch? A: There have been actual reported sightings of the Sasquatch.',
#        "There once was a man and a woman that both  got in  a terrible car wreck. Both of their vehicles  were completely destroyed buy fortunately no one  was   hurt.  In thankfulness the woman said to the man 'We are both okay so we should celebrate. I have   a  bottle of wine in my car let's open it.' So the woman got the bottle out of the car and  handed it to the man. The man took a really big drink and handed the woman the bottle. The  woman  closed the bottle and put it down. The man  asked  'Aren't you going to take a drink?' The woman cleverly replied 'No I think I'll  just  wait for the cops to get here.'",
#        'If pro- is the opposite of con- then congress must be the opposite of progress.',
#        "Q: What's the difference between the government  and  the Mafia? A: One of them is organized.",
#        'Q: Ever wonder why the IRS calls it Form 1040?A: Because for every $50 that you earn you get 10 and they get 40.',
#        'Hillary Bill Clinton and the Pope are sitting together on an airplane. Bill says "I could throw one thousand dollar bill out of this plane and make one person very happy."Hillary says "I could throw 10 hundred dollar bills out of the plane and make 10 people very happy."The Pope chips in and says "I could throw Bill out of the airplane and make the whole country happy."',
#        'An Asian man goes into a New York CityBank to exchange 10000 yen forAmerican Currency.  The teller gives him $72.00.  The next month theAsian man goes into the same bank with 10000 yen and receives $62.00.He asks "How come? Only $62.00?" The teller says "Fluctuations-Fluctuations!"Whereupon the Asian man looks back at the teller and says "Fluk youAmelicans too!"',
#        'Q: How do you keep a computer programmer in the shower all day long?A: Give them a shampoo with a label that says"rinse lather repeat".',
#        'What a woman says:"This place is a mess!  C\'monYou and I need to clean upYour stuff is lying on the floor and you\'ll have no clothes to wear if we don\'t do laundry right now!"What a man hears:blah blah blah blah C\'mon blah blah blah blah you and I blah blah blah blah on the floor blah blah blah blah no clothes blah blah blah blah RIGHT NOW!',
#        'Q: What is the difference between Mechanical Engineers and Civil Engineers? A: Mechanical Engineers build weapons Civil Engineers build targets.',
#        'Q: How many Presidents does it take to screw in a light bulb?A: It depends upon your definition of screwing a light bulb.',
#        'A neutron walks into a bar and orders a drink."How much do I owe you?" the neutron asks.The bartender replies "for you no charge."',
#        'A man recently completing a routine physical examination receives a phone call from his doctor.  The doctor says "I have some good news and some bad news."  The man says "OK give me the good news first."  The doctor says "The good news is you have 24 hours to live."  The man replies "Shit!  That\'s the good news?  Then what\'s the bad news?"The doctor says "The bad news is I forgot to call you yesterday."',
#        'A Czechoslovakian man felt his eyesight was growing steadily worse and felt it was time to go see an optometrist. The doctor started with some simple testing and showed him a standard eye chart with letters of diminishing size: CRKBNWXSKZY. . . "Can you read this?" the doctor asked. "Read it?" the Czech answered. "Doc I know him!"',
#        "A radio conversation of a US naval ship with Canadian authorities ... Americans: Please divert your course 15 degrees to the North to avoid a collision.Canadians: Recommend you divert YOUR course 15 degrees to the South to avoid a collision.Americans: This is the Captain of a US Navy ship.  I say again divert YOUR course.Canadians: No.  I say again you divert YOUR course.Americans: This is the aircraft carrier USS LINCOLN the second largest ship in the United States' Atlantic Fleet. We are accompanied by three destroyers three cruisers and numerous support vessels. I demand that you change your course 15 degrees north that's ONE FIVE DEGREES NORTH or counter-measures will be undertaken to ensure the safety of this ship.Canadians: This is a lighthouse.  Your call.",
#        "Q: How many programmers does it take to change a lightbulb?A: NONE!   That's a hardware problem....",
#        'A Panda bear walks into a bar.  Sits down at a table and orders a beer and a double cheeseburger.  After he is finished eating he pulls out a gun and rips the place with gunfire.  Patrons scatter and dive under chairs and tables as the bear runs out the door.  After ensuring that no one is hurt the bartender races out the door and calls after the bear "What the hell did you do that for?"  The bear calls back "I\'m a Panda bear.  Look it up in the dictionary."  The bartender returns pulls out his dictionary.panda : \\Pan"da\\ n. (Zo["o]l.)A small Asiatic mammal (Ailurus fulgens) having fine soft fur.It is related to the bears and inhabits the mountains of Northern India.Eats shoots and leaves.',
#        'Early one morning a mother went to her sleeping son and woke him up."Wake up son.  It\'s time to go to school." "But why Mama?  I don\'t want to go to school." "Give me two reasons why you don\'t want to go to school." "One all the children hate me. Two all the teachers hate me" "Oh! that\'s no reason. Come on you have to go to school" "Give me two good reasons WHY I should go to school?"  "One you are fifty-two years old. Two you are the principal of the school."',
#        'Reaching the end of a job interview the human resources person asked a young engineer fresh out of Stanford"And what starting salary were you looking for?"The engineer said "In the neighborhood of $125000 a year depending on the benefits package."The interviewer said "Well what would you say to a package of 5-weeks vacation 14 paid holidays full medical and dental company matching retirement fund to 50% of salary and a company car leased every 2 years - say a red Corvette?"The Engineer sat up straight and said "Wow! Are you kidding?"And the interviewer replied "Yeah but you started it."',
#        'Two atoms are walking down the street when one atom says to the other "Oh my! I\'ve lost an electron!"The second atom says"Are you sure"The first replies "I\'m positive!"',
#        'Just a thought ..Before criticizing someone walk a mile in their shoes.  Then when you do criticize them you will be a mile away and have their shoes !',
#        'Two attorneys went into a diner and ordered two drinks.  Then they produced sandwiches from their briefcases and started to eat.  The owner became quite concerned and marched over and told them "You can\'t eat your own sandwiches in here!"The attorneys looked at each other shrugged their shoulders and then exchanged sandwiches.',
#        'A teacher is explaining to her class how different languages use negatives differently.  She says "In all languages a positive followed by a negative or a negative followed by a positive makes a negative.  In some languages two negatives together make a positive while in others they make a negative.  But in no language do two positives make a negative."  One of the students puts up his hand and says "Yeah right."',
#        "Age and Womanhood1. Between the ages of 13 and 18 ... She is like Africa virgin and unexplored. 2. Between the ages of 19 and 35 ... She is like Asia hot and exotic. 3. Between the ages of 36 and 45 ... She is like America fully explored breathtakingly beautiful and free with her resources.4. Between the ages of 46 and 56 ...She is like Europe exhausted but still has points of interest. 5. After 56 she is like Australia ...Everybody knows it's down there but who gives a damn?",
#        'A bus station is where a bus stops.A train station is where a train stops.On my desk I have a work station...',
#        "Q: What's the difference between greeting a Queen and greeting thePresident of the United  States?A: You only have to get on one knee to greet the queen."],
#       dtype='<U1198')

# %%
ErrorDict = test(dataMat, 0.2, standEst)
# Out:
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.546158272598104
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.4130978263023
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  0.9152961046811868
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.348208832224058
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.0711787347653154
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.554070756049534
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6738007394301753
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.453588636675076
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.853690989145666
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5070665650790573
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3197725616030342
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.0288131634804345
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8768807924212485
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.409469658135324
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.5428852875493675
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.4488074479517032
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.017158625728435
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.183048931306957
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.1548226180829775
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.643638048986477
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.238270566333809
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3785895587805173
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.1270061165663767
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.611500759689053
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.13187202485559
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.1255312082232556
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.419183626953899
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.844348636848589
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.61345129795929
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.523720876255794
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.156265305927384
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.0812538660582605
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8520411946163464
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8779240074264476
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.488468031601414
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.3158850287549395
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.504772655576182
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.2196378366546308
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  0.2741798681648329
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.050467621928954
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.491462607411313
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.771701329457321
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.051018891122364
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6576811050879576
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.0095328661069525
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.135852844227123
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3083790098958312
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.797928817417976
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7223099652295053
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.927371984914604
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4342165459430967
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.750988651750396
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6804660091920445
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.6528658993907515
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.310087560982008
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.826945748261757
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.283126508251604
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.4788140217275985
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.264450958761652
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.546464170480853
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.281337051409555
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.239274678186823
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.68545065014853
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.2487961273677337
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8400280914581484
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.8548156101893625
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5792927048070478
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9707349359005433
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.400262914282937
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.3459758429459714
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.5105921480363813
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.2112692060017167
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8049996085798419
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.384010205873481
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.138395166267632
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.0963592052887012
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.094845341389427
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.1663728811681078
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.249084499863576
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.836452976160227
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3174377961798007
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3280387396942204
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.355626367635097
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.3783647823081795
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5374700035919437
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.865086263419035
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.65479039075234
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.077926509778996
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.386858682919753
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5604918317097685
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.9367883676643527
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.8881977921335364
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.3044275820672375
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3537052883512404
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7399425930440406
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.297459056315916
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.949818698229867
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.6921045170161335
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9720161409011034
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.778478076408134
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.0236385834923265
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.318751223345051
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2381486556229566
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.3109009712755926
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.629659139026143
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.319272723668758
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.006897667147419
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.2576587182456058
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.708580907310811
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.567513116077497
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5536785035664693
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.6917498713370707
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.930018310723637
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.768220488066502
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3013744730666397
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.09114266189213
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.49727335290485
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8912997774812945
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.9123049464340935
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.564672641325003
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.482309509627625
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.3464706500888366
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.603499092362289
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.549586080280828
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5270639771411543
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.911882942966329
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.458674355644225
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.2022598429233637
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9488592612146167
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.655907323864965
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.6196327667456005
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9310033047525192
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.223176928968011
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.049195557224912
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.092999326552243
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.819341103042241
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.579570962134006
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.355867099352515
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4929987731712524
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.345274257297229
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.371190043649193
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.174302101478892
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.907155758405338
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.748334736260635
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.1636890310549366
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3724313531884262
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.609637943809981
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.547613354826076
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6012788281450785
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5577372108863092
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.889482315010774
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.140563382748842
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.840515379781463
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.938259493485771
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.941551297284991
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.350470409962213
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7016556355935224
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.317416656435486
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7088950622101664
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4056123761265855
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8299663487916393
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.403318290744101
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5869753187901563
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.154859851315117
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.249304188102353
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.026910105324201
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4363262408441857
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.34664107195752
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.819729118695347
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.797994531566399
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.374403718588081
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.3877292785226976
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8749853372360303
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.716729718898827
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.55587601952164
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  8.058612029144566
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6129844311808466
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.217441534581037
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.034314266483189
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.602810216531859
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.5384434148696813
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.019647839155614
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8867439974542237
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.1899919490752158
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5678947927415394
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.308576638401759
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.1794463546123004
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.307118027416143
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.834032044792484
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.903172783589807
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.147483062433786
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8622939888072625
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.798680802548708
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.635683096107114
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.925447494788892
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.824773624943935
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.3637120870366526
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.427614118715133
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.138009073355504
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.279540160263262
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.846671503385564
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.097246277044715
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.275290442125623
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8579564290095811
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.20993638347412
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.668935395338182
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.496436772245238
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.450271170376395
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.942522855813961
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.7008065390416072
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.75302812380582
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.423882795800727
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.302805388437759
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4060548537830075
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3271660180298746
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9329715339307643
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.3191408930641426
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.228406156546354
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.913709910225724
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.850157922240768
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.216915612829495
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.103589236021016
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.056541371800302
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.2413084522727666
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9138802145862925
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.480364012621782
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8585117061436693
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.473818639007618
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.3081456961279505
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.2550130250382665
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.300113333478269
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.193978375447294
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.815106258217921
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.6632415928410103
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.63133588775873
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.793002848472112
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.276991211283466
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.116603258649635
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.801126466568518
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.920767575893569
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.527001928309545
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  0.45064613938822157
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.011284341578912
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.6807665487106775
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.297807576236266
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.5399470617719513
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.80360348475441
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.759763372697836
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.6281216587323155
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7562960365353413
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.185891138112281
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8214203188919407
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3616607191722276
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5804740517178546
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.888789254138876
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9887309210078665
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.625440683705965
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.4694593006166086
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.0886717249519253
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.889405329097191
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.673099625334126
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.308134316473878
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8308414518672849
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.896769144515928
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.808380678757081
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.0862047887908037
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3065008621642598
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.235595040214164
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.366169114949378
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.959636274367585
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.396004990938316
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.9755175259939333
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7565316276842062
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.6229561269754544
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.0429332498522386
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.414051984637906
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7836730415641524
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8769562037138354
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.329660998538478
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3878097512108853
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.913016468700482
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.19323390326434
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9312846616685682
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6857972230077167
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.824041497558317
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.491134462294122
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8260293231190843
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.53228938238202
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.661431429193727
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.0553503955342
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.901487406475416
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.606971192035277
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.202225343090694
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.6287281150024409
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.712157246522185
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.7388724926705896
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.569675895655339
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.63892486735403
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7619880152577685
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.776467639940558
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.6383158048897464
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4341722805223207
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.0968643715102386
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.538096661620438
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.4923303032414426
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.31660098314253
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.903863972684539
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.601999112605913
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.137993072107004
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.078775596895167
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.709700150152983
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.753739158448369
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2586282618680933
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.213200763662485
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.2505698715316926
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.76495676506346
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.778929076953879
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.6513838716409932
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.489995992887814
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.137543562097965
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.596880737942748
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.5302235200036387
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.354013989555661
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.1314771771604555
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.5050506199391265
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.324223842183622
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.277254335500912
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.9857116465418825
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.9275500005536657
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.619490954342937
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5573237450844195
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.534714753719265
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5964548570867954
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.1833676021716912
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.942444498321745
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8243832451471724
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4609406424937257
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.9926747661699045
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.252616282757661
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.640892518082375
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.4692443460311932
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  0.9505071678509956
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.997726829074056
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.029082134515009
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.353170119054409
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.581864934826019
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.409482137972009
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.630126742328046
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8057527996740474
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.591931560913219
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7719682112157327
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9954005377177395
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7413531018714443
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.774741838522406
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.853409838403522
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.028936409110488
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.83124881183308
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.149019239344215
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.0419788484440864
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2599867250637793
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9274876711958244
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.468592165311333
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.721927965175208
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.34457589969324
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.658386604200288
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.374969582335363
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.241496509056485
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.593390471703048
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.2612075450404285
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.572791044879052
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.406248992589607
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.5048270659500815
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.655379843570476
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.625242213502101
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.479898044446382
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7303957566600485
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9135623546544918
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.2556280122675267
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.2079251762111785
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.789481029190509
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.155104045311338
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.1560266213175066
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.185147404369095
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.0707454426154
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.083871594990195
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8194728676309169
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.9523116267811655
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.685826861063441
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.136543940571083
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.5747722437600356
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.247851044677067
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.972069775516237
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.04318556708432
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.015846645897157
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.2513135640759945
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.83621409184942
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.203974972402409
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.5383118804050095
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.269467273232703
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.072588221170557
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5938362777210044
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8030362442600394
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.333985938919906
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.580320673627514
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.4431485628203329
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.335609374784167
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  8.126820016215557
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.231890547160607
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9623548838633442
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3155310269501674
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7873458841876055
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.427301400163905
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.073364948908943
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.426164580852877
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.358016519761307
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2518578154081186
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.2888067658577675
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.304926984813397
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.474580082647012
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.10828772001153
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.509245980767073
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.048744512353433
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.4069024025433565
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.453246463450696
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.2184825406447755
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.115608159435236
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.750330521490018
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.3477571165770765
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.0208510015919823
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.293703701265307
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.269226467216142
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.918548738273765
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.264180299940888
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8296544347745116
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8130773979950225
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.013166292460909
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.1727169635442833
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7154356047285972
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.6794901407538045
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.4448163418689575
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.634890313281631
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.048962221056094
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3610566048208477
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.560970637876058
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.126075190910707
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.074843415302553
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.888092167583984
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.292849961305994
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.266151416202313
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2693057318634113
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9627700034621247
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.866476717263749
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.906509068648657
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.690373003804142
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.3894775024179484
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.7932892228214135
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.38987199189664
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3727832733614576
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.357239401808358
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.267140857620455
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.642176494638467
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.0498019880003304
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.454959842436366
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4280690955644664
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4825875203608163
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.455558566044298
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.6800834735274917
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.1810671709737466
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.3330914399369447
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.7985716765336255
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.972964352235797
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.00522082631806
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.438323032241795
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.389916691215864
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.014546403750125
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  0.6987924069514345
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.538802642492802
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.0653433398089827
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.234585503878576
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.85227872946269
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.059122309175259
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5755841479166093
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.687067861795276
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.1945597872549898
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.0942408558088483
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.3682163152803064
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.304217235211839
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.359211436188654
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.34026452287222
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.539772407914652
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6555488307167048
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.1862168383425225
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.878466753133661
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.784438017560533
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.280108903240695
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.9311196817867855
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6376738851968113
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.142007351562609
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.501605228606639
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8913153252812527
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.4472574053731675
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.5661583347936805
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.214390689590043
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.668810095947796
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.33702576138864
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.977371685064444
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.048329020186097
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.1785482815880224
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.084082264600022
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8304487480902003
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.85735815551792
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9486949809851941
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8933631861142182
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.339525533531651
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3580334458720538
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.2854660680666132
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.102233137358449
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.560655882491163
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.0807720315745355
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.401964578837106
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.530833527097535
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.355999891287236
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.199792816401481
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.4977424917167617
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7654208030978764
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.15688656079078
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5629046406426306
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.5976341325280745
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.750885273628904
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.97930332803733
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8847978152528737
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.415999727776792
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8566515909484016
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6558955181898787
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.841331829232853
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.521084602358374
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5951810623911866
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9645952913404006
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.955791146210547
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.777711321978323
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.219973766288681
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.738493258110458
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.8940432060808
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.692121516575395
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8494286511317743
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4258193372666583
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.484726445629254
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.1336623869062383
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.754628840823292
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2400957034297173
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.757180214843563
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.431752610951068
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.4505292948273425
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6839119923063604
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.0827768448785875
# ...
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8860512874721267
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7457505898779573
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.770187697502279
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9404509419608393
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.113072405418109
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.644616347198055
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2396301015247593
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.5260936147363715
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.2096695396729953
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8254540410570192
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.1205149551562075
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.249859730716978
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3911793406812967
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.6659339003203069
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6573562542979445
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.743416320021363
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.689758169521139
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.65624789686757
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.6128713542279245
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.721882831376777
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.0770332772485665
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.9497559956506905
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.0850230449351614
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.484869786848107
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7472732229661103
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.409665317100092
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.164897779190073
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.573907394739611
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.878815473867125
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.813455593075086
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.7501864916450418
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.7428016531745065
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.595610545842744
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2784845653358636
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4527305996151325
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.922139580220267
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.339567578728519
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.764896630411137
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5106106987212735
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.817406591632652
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.188701748288373
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.700894134659516
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.651585270101338
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.950309192321964
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.111254256292555
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.805699488123114
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.138966627449988
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5637729856686828
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.596810353153732
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.1061673781716572
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.485280053167204
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.679236342789429
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7381254261241423
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.833049381280973
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.340310276424711
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.387725999684471
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.6097449683803395
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.706733835651262
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.95433101089198
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7222307504780803
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.1015542524477233
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.664203347232621
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.557492799682856
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7389255679611964
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9229387306413717
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.519278883545459
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.085129691280906
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9516032821289895
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.052160467339542
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.630884342904845
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.085795638566753
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3397144239454035
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9370323549800674
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.699707580333718
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9296847799278767
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.538237797363144
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.429820001740535
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.50738347507477
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7129874127327986
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.0246936791574015
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5002450553005797
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.597563138302471
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.92567838611187
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.2669000453308217
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.61972820270183
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.120507228455841
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.76135757825848
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.988350042063419
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.69145983501706
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.936705073437806
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.2277117519491076
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7834419527945453
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6345148230478452
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.048459128906047
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.372115410983953
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.5703644241745476
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.355252730258434
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.1995814181248052
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5762384705220116
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.394168632484414
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.931592372051547
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.121670395328105
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3838734750417068
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.7392726392856988
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3576290482308355
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4625753119524902
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.30940843131111
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.289244171855728
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3788546591585735
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.3071584333556645
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.3977237717758983
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7751140486494146
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.6906667791280032
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2743680956474988
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.7701567604251536
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.45392889414537
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9357238118455706
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.627705975955856
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8113398536025627
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9909906589075017
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.44454799374299
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.4387886852775957
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.335268356150693
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.9685750236262343
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.6941319636086973
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.3633146883500653
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.389145813190452
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.110632664218111
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.6157551019386627
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.678707831019515
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.179305372669754
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.61039071474407
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9980935406535307
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.348940751690228
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.432823687626066
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.601977954590514
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.373656348755228
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.562328362297856
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.047663560754171
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.355924507694696
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.011323458812664
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  0.3003121266022609
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.604248449765079
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6952072680795403
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.394866834835204
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.252745602725215
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  7.1702318475445
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.103829052796116
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.003783372736705
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.4795444624440197
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.2240063102564416
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.7227108085728466
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.0187116804179586
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.324234234107521
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.3694298082322836
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.180996135341867
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  0.9361472259810573
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.663333623624354
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.4065358211225205
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.536199590777794
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  5.175725024734081
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.105119715320058
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.8919015768644603
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.7816598129523247
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.735030548574394
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.0419384326452221
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.364901201196085
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6700834476771713
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  4.5522011637259
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.157559268582781
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.302692237627252
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.5447249657651596
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.9116198861762257
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.692916961981348
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  6.590895435780852
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.8577428384083605
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.970724701390634
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.633739758154978
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.8388269880207124
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.1831696741464888
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.660065669084252
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.6167018871542598
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  3.5027807122716896
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  1.6484003947205106
# Mean Absoloute Error for  <function standEst at 0x7fb305787940>  :  2.028122803266041

# %%
ErrorDict = test(dataMat, 0.2, svdEst)
# Out:
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.975859526739977
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.074349309132254
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.6020812059906593
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.708574436139643
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4018577502458
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7686063282667486
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9748080759158337
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.693819780458382
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4289241117566562
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.4618639910120277
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5622415201385729
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.6817116859688825
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1244115433135335
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.44366290123865
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.011141537748176
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.169839287675669
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.138864728371757
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3585290881878023
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5594749609022793
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7324582929249006
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.9823530553505001
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.568829586787635
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.232716291864625
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.215925527615962
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4115295009949955
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.477939502796686
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.660278347285171
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.263710736386284
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4061972164182484
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.934399021162624
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.883337580477008
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0745036835494113
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.17963591982722
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.6613208059472813
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4990402140177497
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.6285726971728565
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.8044171791472543
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5381572791744063
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.19038997502702726
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.009187622926844
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.178302478748734
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.447066342787668
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7176754812467743
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.879545371707612
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.2095426349281775
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.860598802973048
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7064775132346264
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.159872667076193
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4871156397242955
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.570468362615396
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7721769689462215
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3271672317547467
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.065771041908103
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.318425665456367
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.016315942228583
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9151674804918413
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.222756950042317
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9369715739855757
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.3081570790423545
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.324325523505205
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5545739781287073
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7566516078273287
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.781668507167163
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4651815847654897
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7788648447701667
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.701507527418807
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.8701830934602963
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5075077203395684
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  8.022270087236054
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.7706886082038698
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.427579597891171
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.2587089078560227
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.7733613003220043
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9833502675596444
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.549937362632248
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  7.074348156710274
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.68506593679795
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.396306609050462
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.63556170144431
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.6115249358934467
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7139675368253036
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.134803879074569
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.767855547549533
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.206932280154073
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.904107322229553
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.239427530332867
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.1986327766765505
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.2079475039297694
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.016447534748717
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.1854060513278
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3207880088999437
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.131879065120202
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.809304508892311
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.708502817397538
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.314927468997001
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.996367363554576
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.132621337971602
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.168558598048955
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.285248041602168
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.91519544184696
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.391593674285789
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.848185975974175
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5173513278114226
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.968433464572113
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.364187582110463
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.4930423352109194
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.658761514740727
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.220924527507882
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4928555432610153
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.336374010433734
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.0730829121572962
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9623390300195453
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.630664610979453
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.431543169516969
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.188323449423832
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.718194502848355
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3715727209285222
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.611291322997713
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.772956384685582
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.302138529462513
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.198778843216955
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.713179703243578
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.273486937384209
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.6566539877036774
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.107471611542847
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5837273918602515
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.198622132388869
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.034813578716552
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1829244341020204
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.16568955760835
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.155573011611471
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5197920960265314
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.60236311322468
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.059964888478155
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.813450417995607
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  8.701667422800446
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.6621461207607435
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.159085483315312
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.537586938652329
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.8956324058229725
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0135684835730943
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.351588773297728
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.447713979707796
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3539508081261764
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.880234280113588
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9642994446410293
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.8537860091119702
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7823840072555464
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.8742666425638768
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.004714060349908
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.4835386752418085
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.735661472391553
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.6970792293440473
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.315571619490443
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.466451345377329
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.662132721651247
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7544607849024487
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.905679857829497
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.570729485881838
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8122496802242383
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.053098516866088
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.372349524894024
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.615902676594468
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3694762789358665
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.081094729979274
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.616913917242533
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.2571168158094963
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.438380473180369
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.467591447081171
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.532185250853125
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  7.693224618601724
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.245551796853918
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.652754547527976
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.0841820683605623
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.40150312960305
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  7.740549183302597
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9742982726843277
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.637197923176286
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.1948981383942567
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.3436474812861885
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.22033971526305
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.881524569628467
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9963522514183154
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.976596431562401
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.543815772588444
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.322496687964268
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7894954773706573
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8186476779024146
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.484987332154183
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.134256129002551
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9455852277725705
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1007624448757105
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1796321666151854
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.765811081665435
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.5015302447395085
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.615495141307796
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.567818975376827
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.1913513985290236
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8969093341647585
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.6382325453548594
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.693915192677643
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.14637093975728
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.11449536391528
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.60987803643056
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7143515376810834
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.110771937987876
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.740691086576012
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.6047547910602185
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.260133342226739
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.1930439921076297
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.053286915855524
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.738555244785438
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.563401882425176
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.8527568835396186
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.681928133095453
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4611986172693214
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0003847793053255
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.1433565482370645
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.574069073085389
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.633911068567192
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.513888581564177
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5590856467613106
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.399939301819684
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.9968115103247054
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.7519961529872992
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.996390954646538
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.352035879926748
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5803826092357625
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5702071593271136
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.205906293286079
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.595679676781405
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.553192021314948
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0614412665981177
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.435331511633816
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8320695511868936
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.123970394660298
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.624018125954587
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.7348058667179265
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9635798287410813
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.9855840236851865
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5700795957796108
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.5832786670385793
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4465199058317215
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.604638863972135
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.189702400017961
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9019998828079714
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  7.117255737831492
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8098260649114186
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.085844229728509
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.674077779288014
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.948118213094752
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.6108504648050168
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.128128685492323
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.921486793022685
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.557981421995243
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.161731899666166
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.677406516051355
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.664333357148436
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3169564472679167
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.509779181749821
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  7.025506639053125
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.539216025452218
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.506480824878893
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.025706271280753
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.428368064910729
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.29543102184163
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5448990382505405
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.232176478528006
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3596408144889054
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.207580494133225
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.078738242469047
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9556746311455253
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.979561267994424
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9713034416861068
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1220613691025068
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.1534737087609805
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7784187229259496
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7002790997716293
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.2746999484274815
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9197713472695668
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.643703344175576
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.348856621779395
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.819065506085777
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5625675452218166
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.2892146515564225
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.066332027399826
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.0778204635696067
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.248938832446642
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.869794300687281
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.484408328808797
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7900505752497375
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.8926686174622405
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.3896207512031555
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.0402134688429006
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.42025864482149
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.030045850608164
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.1720786299265225
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.160164888952768
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.051047204250843
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.980062401430453
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7009044596622944
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.6208406272740437
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3279827383024942
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.896528242875697
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5205950682401785
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.5346048620162405
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.790224958274068
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.026323463917559
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1506213291524245
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.284591888399366
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.2510571546929095
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.072695072426861
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.983306991294422
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.67090503225577
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.861772504797702
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.363889662841911
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.585138721898214
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.4389297385569828
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.726303515855681
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0716002171732764
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.886964683830974
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.0322682265156855
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1985696380095674
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.902521956996537
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.461344161484374
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.113053679013225
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.0999508318896845
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.2806665098300805
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1463745300286505
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.6046077921451194
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.716533664330723
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1412306091992197
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.2498387443725294
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.994958360242358
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.127553117103423
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.6009348520834537
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5373726201588613
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.0206667822520705
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.426003165939926
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.655496456565827
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.982812945297046
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.7901428090949117
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.594455512468789
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.626615720102334
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.581836731482577
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.6047440078752393
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3800684264483913
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.886458683285319
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.2895944116508598
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  7.780700293067021
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.414169601528088
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5634065215552693
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3797326596305126
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.031325305357635
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.554960636596546
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.522794710749836
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.925695430056076
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.313420941770564
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7680497050379143
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.712392559303006
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.582454217247084
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.2513741514484487
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3102285149281863
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.261376075854611
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.194288434619329
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.268085154304329
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.720435313029612
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.121685097925284
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4617455621149
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.861824165328705
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.3133843586778635
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8414308658427636
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.613670453738922
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7466217540043614
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.047502400365952
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3666235080412643
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9993320685051996
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.827720107549086
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.621910551256832
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4346220770037292
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4541793350288907
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.2179880007315536
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.782767569107998
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.555602633105099
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.415258942018977
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.2353003963165399
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0663795143699786
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4873131190933107
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.543205637354802
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.011029083186524
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.779422685470521
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.432257839584422
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  7.40590843009244
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.429553254767702
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.07023484994549
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.367981886545505
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5138355180831167
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0136481449148547
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.2838141894313033
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.983405377565951
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9899471301657194
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.186606064537591
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.104330551517936
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.75173108450643
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.6143517004924017
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.196657727766982
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.270425308232137
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.911070348483556
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.8481767500985322
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.331261083393311
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3042497138148668
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.834742739047123
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.0128991667336518
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.9211249494191565
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.6742135575058765
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3465254434450875
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.418534230476814
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.731568440844402
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.647655471717958
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.276510509999257
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7703629778044947
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.4509759086807061
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0453734962910888
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.623845780452531
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.195791608850751
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3352656083318584
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4410424452970365
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.420318331818133
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.9357556648828876
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.972634551110881
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.36996332914867
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.885418666162506
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.535665799034751
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.8082599895090974
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.233841290519484
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.564329365760254
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.6205505253189707
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.283797900559061
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.5103614540882235
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.780174095383792
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0355176834893474
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5986587089844266
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.608552485656709
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.277181172012206
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7856217917875896
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.8127669553380787
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.116623428045708
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.50247872672573
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.102301507373228
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7831664186629714
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.989012752900598
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.282518194836308
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1333871647915013
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.448198720771397
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5462612799140714
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.741446064166003
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.383087003662245
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8382568180022694
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7667011790417866
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.112410823362316
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.701040973594094
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.6208355824232166
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.471159426210628
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.8036299163273535
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.346691302511245
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.158931398417208
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.408567120804902
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.8145901898178336
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.8081884325616377
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5683582175823227
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.9004639069929885
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.228629821353496
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9821088328694114
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9563676075352703
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.296105014876845
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.2827865464276604
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.718671835607375
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.881934231377591
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.890607884291251
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.992084773596308
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.376052852222846
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.8506976167690072
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1694666602547916
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.0823064986415387
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.2509456882582075
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5932602286977502
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.665155457133537
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.756286938619593
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.626403436622359
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1039573033902546
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8400621048909116
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9831714681974035
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8902117507703395
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.2840926448925365
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.709838048690913
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.079716880736383
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.393338632533539
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.305722385256409
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3709211588329695
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.063284078632394
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.238001517853209
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4817869735228806
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.142472727091444
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.029255812521755
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.036266735691949
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3572795300091784
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8225251497919723
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.21626037727666
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.7111919412855014
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.173835452073346
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.747083026288582
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4354221759545815
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5803773091832696
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  7.861129286150235
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5481607498229564
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.4415989250410615
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9389437898012605
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.636738780862321
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.4927098714403426
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7383716568683822
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.945130318946964
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.586716867567944
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.106087774894684
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5310281422250105
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.907871670277317
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.35348724728934
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3860783618292603
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.93018142633137
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.969349770606544
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.7287292232387514
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.287929801323208
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.525333709404136
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.6748195400346293
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.791027566761752
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.30234467457221
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.858877556920144
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9875373903807214
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.708303078325176
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3445640947508313
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5461590298290844
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.511295500036147
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.540346492939407
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.945706964077904
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.95968392582395
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.628827864350056
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4865995032024033
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.2385434570526765
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8815720631372934
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.769465164470588
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9385669741623928
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9876828858189204
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.952303047212146
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.0630987506158465
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.886066838156866
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.606065723028008
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9036113088202025
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.1195799342671884
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.8563068055716354
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.2089251951532605
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.8530320944071947
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.8810576868573867
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.089214432186411
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.002855926645148
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.0091091852517406
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.359939201209692
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3115622596742855
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.0299584904435153
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.917460587870003
# ...
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1346656492044755
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.8353076810129485
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.344961512652701
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.7399301717239835
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.2410333890649827
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.650949054118625
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.017182639918217
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9629590273219906
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.479896665158685
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.034272025070148
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.254180599795731
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.32707641054501
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.220779471931808
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.2918616478607485
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.433957638945559
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.398289974747064
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4475486253826317
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9853496029541946
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.032122037394745
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.560153988157083
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.043991691093946
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.296919391662956
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.14982533257934
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.2448152023942707
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.6280900929923754
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.434247205816957
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.649312476564367
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.0203177428914385
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.662706572021739
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.261367934714643
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5945989329571097
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.160334711055461
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.2399633974691247
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.7482671916956845
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5069018007609079
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0763417453521136
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1466354091413797
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.487670245341176
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0802802891963794
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.155802928907296
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0771706589517196
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  7.567902876100583
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.180019665392517
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5396262932116125
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.8907154972719113
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.821687280252813
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.956352669149819
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.727088058568938
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.922339706439806
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.544950133587751
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3174273140741053
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.882512181295764
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.824774522440116
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.6924784301352964
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.2151530281704925
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.237543627620812
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.221804409332449
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.875657093097151
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.62019153272955
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.368746426545562
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5887242985893293
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.481915721536918
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4909394228728456
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.754726787150358
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3201891411907067
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.4530215865976635
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.818214819608975
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.3078791661879916
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.911922763201077
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.167263167809834
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7132186913946423
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5807969075361257
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3164559083375047
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.455843126542487
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5034703767553927
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.461785668903875
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3811840705083798
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.6160232592781463
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.9206608668792677
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.148187588941989
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.96415035803508
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.418849441113903
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.565840562333866
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1241640305757956
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.058950670803147
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7981026893157526
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.6082132523893
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.876681388115524
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.27752439675014
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.385261449427481
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.182735015492054
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.713158239549794
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.86847424414292
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9385834370382033
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3746076304397583
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.2053697216645
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3338537392799727
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9131065133404908
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0247655476776742
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9751640796488317
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.810673089915389
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.541304415740816
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.587736189152286
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.746705715852299
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.885425488541059
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.69230299369254
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.507639961586351
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.3565204597227818
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5533931921801454
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.093177883022912
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.078789643561208
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.612893662364173
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.110167833703954
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.775043296993318
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.471036012718298
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.445471783937569
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.7226183670746966
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.55201264619604
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.451891593257109
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1387944887545935
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.173552329019807
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.770036070805555
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.2082139291116007
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9176935921370446
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.982882931663045
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.183064372139187
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4870167030878454
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7819193445456047
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.2305710082220873
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.524491796811039
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.629664212897955
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.3384426062510815
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.409776850816465
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.1102538636058084
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0049839109744214
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.649100437233133
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.177117893829941
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.1343632057261352
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7861715346706704
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5582464909735823
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.525380172614656
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.181539778576727
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.845835981053133
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.3834706205650429
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9302111444461585
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.3371266634740972
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9661310756311567
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9120774883066334
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.19823627499286
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.643788003983579
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  6.285623516947381
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.9727454799915947
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.626518684773693
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.679735816557503
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.7884274863782355
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7767889293555976
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.8163329216263656
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.4572510610045546
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.01624511995468
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.480580672811056
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  0.9990289594483674
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.267885012145475
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.117942526653898
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.84810615588313
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.761403255084013
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.5263440649870317
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.5250114421567782
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.357104899483845
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.067289833429578
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.1356893997042654
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.362308058060677
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.425990594337325
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  5.5893620257836645
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.0616996796858893
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.059452714550088
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5927752511804805
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.6649161477006156
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.992883368979201
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.426417883465576
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.2526635847015735
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.164374106745917
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7817899452700856
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.7266436337540623
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.9009943248483665
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  3.4565770686154687
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  4.202029202166768
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  2.5345944343657747
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.4421883008125236
# Mean Absoloute Error for  <function svdEst at 0x7fb3057879d0>  :  1.731500968997518

# %%
print_most_similar_jokes(dataMat, jokes, 15, 5, metric=pearsSim)
# Out:
# Selected Joke: Q. What is orange and sounds like a parrot?  A. A carrot.
# The first 5 jokes are:
# A dog walks into Western Union and asks the clerk to send a telegram. He fills out a form on which he writes down the telegram he wishes to send: "Bow wow wow Bow wow wow."The clerk says "You can add another 'Bow wow' for the same price."The dog responded "Now wouldn't that sound a little silly?"
#
# How many feminists does it take to screw in a light bulb?That's not funny.
#
# Why are there so many Jones's in the phone book?Because they all have phones.
#
# Q: If a person who speaks three languages is called "tri-lingual" and a person who speaks two languages is called "bi-lingual" what do calla person who only speaks one language?A: American!
#
# Q. Did you hear about the dyslexic devil worshipper? A. He sold his soul to Santa.
